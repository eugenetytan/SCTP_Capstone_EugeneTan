# %% [markdown]
# # Web Scraping Used Cars on sgcarmart.com
# ## 1. Introduction
#
# ### This document outlines the process of web scraping data from sgcarmart.com, the largest online car marketplace in Singapore, to analyze the used car market.
#
# ### Respecting sgcarmart.com's Rules
# The scraping script will adhere to the guidelines outlined in sgcarmart.com's robots.txt file. Here's a summary of the restrictions:
#
# Crawlers must wait at least 5 seconds between requests (Crawl-delay: 5).
# Specific directories are off-limits for scraping, including:
# cgi-bin/
# images/
# mail/
# dealer/
# directory/premium/
# includes/
# phpads/
# update/
# upload/
#
# ### Data Extraction
# The script will focus on extracting the following information for each used car listing:
#
# Car Listing URL 'LISTING_URL',
# Car Brand and Model 'BRAND',
# Price 'PRICE',
# Depreciation Value Yearly 'DEPRE_YEARLY',
# Registered Date 'REG_DATE',
# Mileage in KM 'MILEAGE_KM',
# Year of Manufacture 'MANUFACTURED_YEAR',
# Road Tax Yearly 'ROAD_TAX_YEARLY',
# Automatic or Manual Tranmission 'TRANSMISSION',
# Deregistration Value as of Web Scraping DTD 'DEREG_VALUE_FROM_SCRAPE_DATE',
# Web Scraping DTD 'SCRAPE_DATE',
# Open Market Value (OMV) 'OMV',
# Additional Registration Fee (ARF) 'ARF',
# Certificate of Entitlement (COE) from Web Scraping DTD 'COE_FROM_SCRAPE_DATE',
# Number of Days till COE Expires 'DAYS_OF_COE_LEFT',
# Engine Capacity in CC 'ENGINE_CAPACITY_CC',
# Car Curb Weight in KG 'CURB_WEIGHT_KG',
# Number of Past Owners 'NO_OF_OWNERS',
# Vehicle Type 'VEHICLE_TYPE'
#
# This data will be used for further analysis of the used car market in Singapore.

# %% [markdown]
# ## 2. Import Libraries

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
import time
import re
from datetime import datetime

# %% [markdown]
# ## 3. Pre-defined Functions

# %%
# A set of functions is defined to extract specific attributes from a parsed individual car listing URL, with each function returning the corresponding attribute.

# Brand Retriever Function 
def brand_retrieval(parsed_listing_url):
    """
    Retrieves the brand name from the parsed car listing URL.

    Parameters:
    parsed_listing_url (BeautifulSoup object): The parsed HTML content of the car listing page.

    Returns:
    str or np.nan: The brand name. Returns np.nan if the brand name is not found.
    """
    try:
        brand_tag = parsed_listing_url.find("a", class_="nounderline globaltitle")
        if brand_tag:
            #print('Brand: ', brand_tag.text.strip())
            brand = brand_tag.text.strip()
            clean_brand = re.sub(r'\s*\(.*?\)', '', brand)# Remove any text within parentheses, including the space before the parentheses, from the BRAND column
            return clean_brand
        else:
            return np.nan
    except (AttributeError, TypeError):
        return np.nan

# Price Retriever Function
def price_retrieval(parsed_listing_url):
    """
    Retrieves the price from the parsed car listing URL.

    Parameters:
    parsed_listing_url (BeautifulSoup object): The parsed HTML content of the car listing page.

    Returns:
    int or np.nan: The price of the car. Returns np.nan if the price information is not available or cannot be parsed.
    """
    price_text = parsed_listing_url.find_all(class_="font_red")[0].text.strip()
    price_parts = price_text.split('$')
    if len(price_parts) < 2:
        return np.nan

    try:
        price = int(''.join(price_parts[1].split(',')))
    except (IndexError, ValueError):
        return np.nan
    return price

# Deprecration Value Per Year Retriever Function
def depreciation_yearly_retrieval(parsed_listing_url):
    """
    Retrieves the yearly depreciation value from the parsed car listing URL.

    Parameters:
    parsed_listing_url (BeautifulSoup object): The parsed HTML content of the car listing page.

    Returns:
    int or np.nan: The yearly depreciation value. Returns np.nan if the depreciation information is not available or cannot be parsed.
    """
    depreciation_text = parsed_listing_url.find_all(class_="label")[1].findNextSibling().text.strip()
    depreciation_parts = depreciation_text.split('$')
    if len(depreciation_parts) < 2:
        return np.nan

    try:
        depreciation_yearly = int(''.join(depreciation_parts[1].split('/yr')[0].split(',')))
    except (IndexError, ValueError):
        return np.nan
    return depreciation_yearly

# Road Tax Per Year Retriever
def road_tax_retrieval(parsed_listing_url):
    """
    Retrieves the yearly road tax from the parsed car listing URL.

    Parameters:
    parsed_listing_url (BeautifulSoup object): The parsed HTML content of the car listing page.

    Returns:
    int or np.nan: The yearly road tax. Returns np.nan if the road tax information is not available or cannot be parsed.
    """
    road_tax_text = parsed_listing_url.find_all(class_='row_info')[1].text.strip()
    if '/yr' not in road_tax_text:
        return np.nan

    road_tax_parts = road_tax_text.replace('/yr', '').strip().split('$')
    if len(road_tax_parts) < 2:
        return np.nan

    try:
        road_tax_yearly = int(''.join(road_tax_parts[1].split(',')))
    except (IndexError, ValueError):
        return np.nan
    return road_tax_yearly

# Registered Date Retriever
def reg_date_retrieval(parsed_listing_url):
    reg_date = parsed_listing_url.find_all(class_='row_bg')[1].find_all('td')[3].text.split()[0].split('(')[0]
    #print('Reg date: ', reg_date)
    return reg_date

# Days of COE Retriever
def days_of_coe_retrieval(parsed_listing_url):
    """
    Retrieves the days of COE left from the parsed car listing URL.

    Parameters:
    parsed_listing_url (BeautifulSoup object): The parsed HTML content of the car listing page.

    Returns:
    str or np.nan: The days of COE left. Returns np.nan if the information is not found.
    """
    try:
        row_bg_elements = parsed_listing_url.find_all(class_='row_bg')
        if len(row_bg_elements) > 1:
            td_elements = row_bg_elements[1].find_all('td')
            if len(td_elements) > 3:
                days_of_coe_left_text = td_elements[3].text.split('(')[1].split('COE')[0].strip()
                return yr_mm_dd_cleaner(days_of_coe_left_text)
        return np.nan
    except (IndexError, AttributeError, ValueError):
        return np.nan

#def days_of_coe_retrieval(parsed_listing_url):
#    days_of_coe_left_yy_mm_dd_format_for_cleaner_function=\
#    parsed_listing_url.find_all(class_='row_bg')[1].find_all('td')[3].text.split('(')[1].split('COE')[0].strip()
#    #print('COE :', days_of_coe_left_yy_mm_dd_format_for_cleaner_function)
#    return yr_mm_dd_cleaner(days_of_coe_left_yy_mm_dd_format_for_cleaner_function)


def yr_mm_dd_cleaner(str1):
    """
    Accepts a string that may or may include the elements yr, mths, and days,
    and converts the whole string into the number of days.

    Parameters:
    str1 (str): A string representing the duration in the format "Xyr Xmth Xdays".

    Returns:
    int: The number of days.
    """
    days = 0
    for unit in ['yr', 'mth', 'day']:
        value = int(next((int(char) for char in str1 if char.isdigit() and unit in str1), 0))
        days += value * {'yr': 365, 'mth': 30, 'day': 1}[unit]
    return days

# Mileage Retriever
def mileage_retrieval(parsed_listing_url):
    """
    Retrieves the mileage in kilometers from the parsed listing URL.

    Parameters:
    parsed_listing_url (BeautifulSoup object): The parsed HTML content of the car listing page.

    Returns:
    int or np.nan: The mileage in kilometers. Returns np.nan if the mileage information is not available.
    """
    mileage_text = parsed_listing_url.find_all(class_='row_info')[0].text.strip()
    mileage_parts = mileage_text.split('km')
    if len(mileage_parts) < 2:
        return np.nan

    try:
        mileage_km = int(''.join(mileage_parts[0].strip().replace(',', '')))
    except (IndexError, ValueError):
        return np.nan
    return mileage_km

# Manufactured Year Retriever
def manufactured_year_retrieval(parsed_listing_url):
    manufactured_year = parsed_listing_url.find_all(class_='row_info')[6].text.strip()
    return manufactured_year.split()[0]

# Transmission Retriever
def transmission_retrieval(parsed_listing_url):
    transmission = parsed_listing_url.find_all(class_='row_info')[7].text.strip()
    return transmission.split()[0]

# Deregistration Value Retriever
def dereg_value_retrieval(parsed_listing_url):
    """
    Retrieves the deregistration value from the parsed car listing URL.

    Parameters:
    parsed_listing_url (BeautifulSoup object): The parsed HTML content of the car listing page.

    Returns:
    int or np.nan: The deregistration value. Returns np.nan if the deregistration value information is not available or cannot be parsed.
    """
    dereg_value_text = parsed_listing_url.find_all(class_='row_info')[2].text.strip()
    dereg_value_parts = dereg_value_text.split('$')
    if len(dereg_value_parts) < 2:
        return np.nan

    try:
        dereg_value_from_scrape_date = int(''.join(dereg_value_parts[1].split()[0].split(',')))
    except (IndexError, ValueError):
        return np.nan

    return dereg_value_from_scrape_date

# Open Market Value Retriever
def omv_retrieval(parsed_listing_url):
    """
    Retrieves the Open Market Value (OMV) from the parsed car listing URL.

    Parameters:
    parsed_listing_url (BeautifulSoup object): The parsed HTML content of the car listing page.

    Returns:
    int or np.nan: The Open Market Value (OMV). Returns np.nan if the OMV information is not available or cannot be parsed.
    """
    omv_text = parsed_listing_url.find_all(class_='row_info')[8].text.strip()
    omv_parts = omv_text.split('$')
    if len(omv_parts) < 2:
        return np.nan

    try:
        omv = int(''.join(omv_parts[1].split(',')))
    except (IndexError, ValueError):
        return np.nan

    return omv  

# ARF Retriever
def arf_retrieval(parsed_listing_url):
    """
    Retrieves the Additional Registration Fee (ARF) from the parsed car listing URL.

    Parameters:
    parsed_listing_url (BeautifulSoup object): The parsed HTML content of the car listing page.

    Returns:
    int or np.nan: The Additional Registration Fee (ARF). Returns np.nan if the ARF information is not available or cannot be parsed.
    """
    arf_text = parsed_listing_url.find_all(class_='row_info')[9].text.strip()
    arf_parts = arf_text.split('$')
    if len(arf_parts) < 2:
        return np.nan

    try:
        arf = int(''.join(arf_parts[1].split(',')))
    except (IndexError, ValueError):
        return np.nan

    return arf

# COE Price retriever 
def coe_retrieval(parsed_listing_url):
    """
    Retrieves the Certificate of Entitlement (COE) price from the parsed car listing URL.

    Parameters:
    parsed_listing_url (BeautifulSoup object): The parsed HTML content of the car listing page.

    Returns:
    int or np.nan: The Certificate of Entitlement (COE) price. Returns np.nan if the COE price information is not available or cannot be parsed.
    """
    coe_text = parsed_listing_url.find_all(class_='row_info')[3].text.strip()
    coe_parts = coe_text.split('$')
    if len(coe_parts) < 2:
        return np.nan

    try:
        coe_from_scrape_date = int(''.join(coe_parts[1].split(',')))
    except (IndexError, ValueError):
        return np.nan

    return coe_from_scrape_date

# Engine Capacity Retriever
def engine_capacity_retrieval(parsed_listing_url):
    """
    Retrieves the engine capacity in cubic centimeters (CC) from the parsed car listing URL.

    Parameters:
    parsed_listing_url (BeautifulSoup object): The parsed HTML content of the car listing page.

    Returns:
    int or np.nan: The engine capacity in cubic centimeters (CC). Returns np.nan if the engine capacity information is not available or cannot be parsed.
    """
    engine_capacity_text = parsed_listing_url.find_all(class_='row_info')[4].text.strip()
    engine_capacity_parts = engine_capacity_text.split('cc')
    if len(engine_capacity_parts) < 2:
        return np.nan

    try:
        engine_capacity = int(''.join(engine_capacity_parts[0].strip().replace(',', '')))
    except (IndexError, ValueError):
        return np.nan

    return engine_capacity

# Curb Weight Retriever
def curb_weight_retrieval(parsed_listing_url):
    """
    Retrieves the curb weight in kilograms (KG) from the parsed car listing URL.

    Parameters:
    parsed_listing_url (BeautifulSoup object): The parsed HTML content of the car listing page.

    Returns:
    int or np.nan: The curb weight in kilograms (KG). Returns np.nan if the curb weight information is not available or cannot be parsed.
    """
    curb_weight_text = parsed_listing_url.find_all(class_='row_info')[5].text.strip()
    curb_weight_parts = curb_weight_text.split()
    if len(curb_weight_parts) < 2:
        return np.nan

    try:
        curb_weight = int(''.join(curb_weight_parts[0].replace(',', '')))
    except (IndexError, ValueError):
        return np.nan

    return curb_weight

def number_of_owners_retrieval(parsed_listing_url):
    """
    Retrieves the number of owners from the parsed car listing URL.

    Parameters:
    parsed_listing_url (BeautifulSoup object): The parsed HTML content of the car listing page.

    Returns:
    int or np.nan: The number of owners. Returns np.nan if the number of owners is not found.
    """
    try:
        # Find the div containing the "No. of Owners" label
        owner_info_div = parsed_listing_url.find(string="No. of Owners")
        if owner_info_div:
            # The number of owners is in the next sibling div with class 'row_info'
            no_of_owners_text = owner_info_div.find_next("div", class_="row_info").text.strip()
            no_of_owners = int(no_of_owners_text)
        else:
            no_of_owners = np.nan
    except (AttributeError, ValueError, TypeError):
        no_of_owners = np.nan
    return no_of_owners

# Type of Vehicle Retriever
def type_of_vehicle_retrieval(parsed_listing_url):
    """
    Retrieves the type of vehicle from the parsed car listing URL.

    Parameters:
    parsed_listing_url (BeautifulSoup object): The parsed HTML content of the car listing page.

    Returns:
    str or np.nan: The type of vehicle. Returns np.nan if the type of vehicle information is not available or cannot be parsed.
    """
    try:
        type_of_vehicle = parsed_listing_url.find(class_='row_bg1').find_all('td')[1].text.strip()
        return type_of_vehicle
    except (IndexError, AttributeError):
        return np.nan

# %% [markdown]
# ## 4. Get Links For All Postings
#
# Links for all the car postings will be stored in a list before accessing them one by one for data extraction

# %%
# Create listings URLs to iterate through
main_page_listing_list = [] # create list to store search pages
for idx, link in enumerate(range(100)):
    url = "https://www.sgcarmart.com/used_cars/listing.php?BRSR=" + str(idx * 100) + "&RPG=100&AVL=2&VEH=2" #search by of 100 car listings per page
    main_page_listing_list.append(url)

# %%
print(main_page_listing_list,'\n','\n', len(main_page_listing_list))
# Out:
# ['https://www.sgcarmart.com/used_cars/listing.php?BRSR=0&RPG=100&AVL=2&VEH=2', 'https://www.sgcarmart.com/used_cars/listing.php?BRSR=100&RPG=100&AVL=2&VEH=2', 'https://www.sgcarmart.com/used_cars/listing.php?BRSR=200&RPG=100&AVL=2&VEH=2', 'https://www.sgcarmart.com/used_cars/listing.php?BRSR=300&RPG=100&AVL=2&VEH=2', 'https://www.sgcarmart.com/used_cars/listing.php?BRSR=400&RPG=100&AVL=2&VEH=2', 'https://www.sgcarmart.com/used_cars/listing.php?BRSR=500&RPG=100&AVL=2&VEH=2', 'https://www.sgcarmart.com/used_cars/listing.php?BRSR=600&RPG=100&AVL=2&VEH=2', 'https://www.sgcarmart.com/used_cars/listing.php?BRSR=700&RPG=100&AVL=2&VEH=2', 'https://www.sgcarmart.com/used_cars/listing.php?BRSR=800&RPG=100&AVL=2&VEH=2', 'https://www.sgcarmart.com/used_cars/listing.php?BRSR=900&RPG=100&AVL=2&VEH=2', 'https://www.sgcarmart.com/used_cars/listing.php?BRSR=1000&RPG=100&AVL=2&VEH=2', 'https://www.sgcarmart.com/used_cars/listing.php?BRSR=1100&RPG=100&AVL=2&VEH=2', 'https://www.sgcarmart.com/used_cars/listing.php?BRSR=1200&RPG=100&AVL=2&VEH=2', 'https://www.sgcarmart.com/used_cars/listing.php?BRSR=1300&RPG=100&AVL=2&VEH=2', 'https://www.sgcarmart.com/used_cars/listing.php?BRSR=1400&RPG=100&AVL=2&VEH=2', 'https://www.sgcarmart.com/used_cars/listing.php?BRSR=1500&RPG=100&AVL=2&VEH=2', 'https://www.sgcarmart.com/used_cars/listing.php?BRSR=1600&RPG=100&AVL=2&VEH=2', 'https://www.sgcarmart.com/used_cars/listing.php?BRSR=1700&RPG=100&AVL=2&VEH=2', 'https://www.sgcarmart.com/used_cars/listing.php?BRSR=1800&RPG=100&AVL=2&VEH=2', 'https://www.sgcarmart.com/used_cars/listing.php?BRSR=1900&RPG=100&AVL=2&VEH=2', 'https://www.sgcarmart.com/used_cars/listing.php?BRSR=2000&RPG=100&AVL=2&VEH=2', 'https://www.sgcarmart.com/used_cars/listing.php?BRSR=2100&RPG=100&AVL=2&VEH=2', 'https://www.sgcarmart.com/used_cars/listing.php?BRSR=2200&RPG=100&AVL=2&VEH=2', 'https://www.sgcarmart.com/used_cars/listing.php?BRSR=2300&RPG=100&AVL=2&VEH=2', 'https://www.sgcarmart.com/used_cars/listing.php?BRSR=2400&RPG=100&AVL=2&VEH=2', 'https://www.sgcarmart.com/used_cars/listing.php?BRSR=2500&RPG=100&AVL=2&VEH=2', 'https://www.sgcarmart.com/used_cars/listing.php?BRSR=2600&RPG=100&AVL=2&VEH=2', 'https://www.sgcarmart.com/used_cars/listing.php?BRSR=2700&RPG=100&AVL=2&VEH=2', 'https://www.sgcarmart.com/used_cars/listing.php?BRSR=2800&RPG=100&AVL=2&VEH=2', 'https://www.sgcarmart.com/used_cars/listing.php?BRSR=2900&RPG=100&AVL=2&VEH=2', 'https://www.sgcarmart.com/used_cars/listing.php?BRSR=3000&RPG=100&AVL=2&VEH=2', 'https://www.sgcarmart.com/used_cars/listing.php?BRSR=3100&RPG=100&AVL=2&VEH=2', 'https://www.sgcarmart.com/used_cars/listing.php?BRSR=3200&RPG=100&AVL=2&VEH=2', 'https://www.sgcarmart.com/used_cars/listing.php?BRSR=3300&RPG=100&AVL=2&VEH=2', 'https://www.sgcarmart.com/used_cars/listing.php?BRSR=3400&RPG=100&AVL=2&VEH=2', 'https://www.sgcarmart.com/used_cars/listing.php?BRSR=3500&RPG=100&AVL=2&VEH=2', 'https://www.sgcarmart.com/used_cars/listing.php?BRSR=3600&RPG=100&AVL=2&VEH=2', 'https://www.sgcarmart.com/used_cars/listing.php?BRSR=3700&RPG=100&AVL=2&VEH=2', 'https://www.sgcarmart.com/used_cars/listing.php?BRSR=3800&RPG=100&AVL=2&VEH=2', 'https://www.sgcarmart.com/used_cars/listing.php?BRSR=3900&RPG=100&AVL=2&VEH=2', 'https://www.sgcarmart.com/used_cars/listing.php?BRSR=4000&RPG=100&AVL=2&VEH=2', 'https://www.sgcarmart.com/used_cars/listing.php?BRSR=4100&RPG=100&AVL=2&VEH=2', 'https://www.sgcarmart.com/used_cars/listing.php?BRSR=4200&RPG=100&AVL=2&VEH=2', 'https://www.sgcarmart.com/used_cars/listing.php?BRSR=4300&RPG=100&AVL=2&VEH=2', 'https://www.sgcarmart.com/used_cars/listing.php?BRSR=4400&RPG=100&AVL=2&VEH=2', 'https://www.sgcarmart.com/used_cars/listing.php?BRSR=4500&RPG=100&AVL=2&VEH=2', 'https://www.sgcarmart.com/used_cars/listing.php?BRSR=4600&RPG=100&AVL=2&VEH=2', 'https://www.sgcarmart.com/used_cars/listing.php?BRSR=4700&RPG=100&AVL=2&VEH=2', 'https://www.sgcarmart.com/used_cars/listing.php?BRSR=4800&RPG=100&AVL=2&VEH=2', 'https://www.sgcarmart.com/used_cars/listi ...
#
#  100

# %% [markdown]
# ## 5. Retrieval of Individual Listing URLs from Search Pages

# %%
# Base url, or you can think of this as the individual car listing prefix
base_url = 'https://www.sgcarmart.com/used_cars/'
listing_urls = set()  # Use a set to avoid duplicates

# Acquiring indvidual car listings    
for main_link in main_page_listing_list:
   
    # Make a request to the website and get the object
    content = requests.get(main_link)

    # Parse the HTML text
    soup = BeautifulSoup(content.text, 'lxml')

    # Find every single URL in the webpage , refer to this post: # https://stackoverflow.com/questions/46490626/getting-all-links-from-a-page-beautiful-soup
    # This returns a list of every tag that contains a link in one main link (each element in main page listing)

    # Find all the script tags in the webpage
    script_tags = soup.find_all('script')

    # Extract the desired links from the script tags
    for script_tag in script_tags:
        script_text = str(script_tag.string)
        if script_text:
            # Find all occurrences of 'info.php?ID=' and 'DL=' in the script text
            start_indices = [i for i in range(len(script_text)) if script_text.startswith('info.php?ID=', i)]
            for start_index in start_indices:
                end_index = script_text.find('"', start_index)
                link = script_text[start_index:end_index]
                if 'DL=' in link:
                    # Remove unwanted part if present
                    if 'u0026GASRC=sgcm\\' in link:
                        link = link.replace('u0026GASRC=sgcm\\', '')
                    link = link.replace('\\u0026', '&').replace('%5C%5C', '')
                    listing_urls.add(base_url + link)  # Add to set to ensure uniqueness

    # Add a delay to prevent getting blocked
    time.sleep(5)
    
# Convert the set back to a list
listing_urls = list(listing_urls)

# Print the retrieved links
for link in listing_urls:
    print(link)
# Out:
# https://www.sgcarmart.com/used_cars/info.php?ID=1316564&DL=2689\
# https://www.sgcarmart.com/used_cars/info.php?ID=1286467&DL=1242\
# https://www.sgcarmart.com/used_cars/info.php?ID=1227438&DL=3811\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333066&DL=1277\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333470&DL=3590\
# https://www.sgcarmart.com/used_cars/info.php?ID=1247890&DL=3837\
# https://www.sgcarmart.com/used_cars/info.php?ID=1311531&DL=3318\
# https://www.sgcarmart.com/used_cars/info.php?ID=1315089&DL=3875\
# https://www.sgcarmart.com/used_cars/info.php?ID=1276589&DL=2976\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334765&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331925&DL=3841\
# https://www.sgcarmart.com/used_cars/info.php?ID=1303818&DL=3337\
# https://www.sgcarmart.com/used_cars/info.php?ID=1223241&DL=4454\
# https://www.sgcarmart.com/used_cars/info.php?ID=1326636&DL=1339\
# https://www.sgcarmart.com/used_cars/info.php?ID=1288409&DL=3495\
# https://www.sgcarmart.com/used_cars/info.php?ID=1278449&DL=4317\
# https://www.sgcarmart.com/used_cars/info.php?ID=1321593&DL=2192\
# https://www.sgcarmart.com/used_cars/info.php?ID=1261189&DL=3456\
# https://www.sgcarmart.com/used_cars/info.php?ID=1318546&DL=3900\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332439&DL=1418\
# https://www.sgcarmart.com/used_cars/info.php?ID=1292840&DL=2277\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334773&DL=3954\
# https://www.sgcarmart.com/used_cars/info.php?ID=1317410&DL=1137\
# https://www.sgcarmart.com/used_cars/info.php?ID=1312946&DL=3810\
# https://www.sgcarmart.com/used_cars/info.php?ID=1326818&DL=4211\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334725&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334540&DL=4641\
# https://www.sgcarmart.com/used_cars/info.php?ID=1316336&DL=2097\
# https://www.sgcarmart.com/used_cars/info.php?ID=1263433&DL=3405\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333955&DL=3382\
# https://www.sgcarmart.com/used_cars/info.php?ID=1326674&DL=4412\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330651&DL=3860\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333684&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332527&DL=3416\
# https://www.sgcarmart.com/used_cars/info.php?ID=1271804&DL=3975\
# https://www.sgcarmart.com/used_cars/info.php?ID=1313375&DL=2984\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332309&DL=1155\
# https://www.sgcarmart.com/used_cars/info.php?ID=1320366&DL=4531\
# https://www.sgcarmart.com/used_cars/info.php?ID=1293372&DL=4419\
# https://www.sgcarmart.com/used_cars/info.php?ID=1293668&DL=1066\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333317&DL=3865\
# https://www.sgcarmart.com/used_cars/info.php?ID=1270325&DL=4450\
# https://www.sgcarmart.com/used_cars/info.php?ID=1323427&DL=3283\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334617&DL=8008\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333759&DL=2341\
# https://www.sgcarmart.com/used_cars/info.php?ID=1329856&DL=2389\
# https://www.sgcarmart.com/used_cars/info.php?ID=1319299&DL=3759\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333004&DL=4313\
# https://www.sgcarmart.com/used_cars/info.php?ID=1312021&DL=4108\
# https://www.sgcarmart.com/used_cars/info.php?ID=1291454&DL=3301\
# https://www.sgcarmart.com/used_cars/info.php?ID=1312675&DL=1195\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333818&DL=2549\
# https://www.sgcarmart.com/used_cars/info.php?ID=1315712&DL=4481\
# https://www.sgcarmart.com/used_cars/info.php?ID=1318309&DL=3722\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331435&DL=1240\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331165&DL=3484\
# https://www.sgcarmart.com/used_cars/info.php?ID=1316599&DL=2291\
# https://www.sgcarmart.com/used_cars/info.php?ID=1278216&DL=2469\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333946&DL=3361\
# https://www.sgcarmart.com/used_cars/info.php?ID=1326833&DL=1163\
# https://www.sgcarmart.com/used_cars/info.php?ID=1328328&DL=2133\
# https://www.sgcarmart.com/used_cars/info.php?ID=1317733&DL=1155\
# https://www.sgcarmart.com/used_cars/info.php?ID=1324077&DL=2296\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334558&DL=3142\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334060&DL=4595\
# https://www.sgcarmart.com/used_cars/info.php?ID=1218137&DL=2976\
# https://www.sgcarmart.com/used_cars/info.php?ID=1312358&DL=4055\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333284&DL=1400\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333315&DL=3851\
# https://www.sgcarmart.com/used_cars/info.php?ID=1293444&DL=3079\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332365&DL=2563\
# https://www.sgcarmart.com/used_cars/info.php?ID=1287507&DL=4731\
# https://www.sgcarmart.com/used_cars/info.php?ID=1328036&DL=8008\
# https://www.sgcarmart.com/used_cars/info.php?ID=1289350&DL=1032\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332888&DL=3597\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331491&DL=1307\
# https://www.sgcarmart.com/used_cars/info.php?ID=1282590&DL=1240\
# https://www.sgcarmart.com/used_cars/info.php?ID=1263048&DL=2029\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333731&DL=1043\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333801&DL=3037\
# https://www.sgcarmart.com/used_cars/info.php?ID=1165528&DL=4317\
# https://www.sgcarmart.com/used_cars/info.php?ID=1299553&DL=1238\
# https://www.sgcarmart.com/used_cars/info.php?ID=1096782&DL=2976\
# https://www.sgcarmart.com/used_cars/info.php?ID=1325788&DL=3475\
# https://www.sgcarmart.com/used_cars/info.php?ID=1305278&DL=2448\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333611&DL=2049\
# https://www.sgcarmart.com/used_cars/info.php?ID=1303855&DL=3415\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334747&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1328257&DL=4609\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334209&DL=1213\
# https://www.sgcarmart.com/used_cars/info.php?ID=1296158&DL=4630\
# https://www.sgcarmart.com/used_cars/info.php?ID=1291865&DL=4574\
# https://www.sgcarmart.com/used_cars/info.php?ID=1325409&DL=1028\
# https://www.sgcarmart.com/used_cars/info.php?ID=1322515&DL=3133\
# https://www.sgcarmart.com/used_cars/info.php?ID=1293584&DL=4074\
# https://www.sgcarmart.com/used_cars/info.php?ID=1325649&DL=1000&utm_content=SLeligible\
# https://www.sgcarmart.com/used_cars/info.php?ID=1257324&DL=3481\
# https://www.sgcarmart.com/used_cars/info.php?ID=1325813&DL=3048\
# https://www.sgcarmart.com/used_cars/info.php?ID=1322378&DL=3750\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332538&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1316301&DL=3648\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334311&DL=4073\
# https://www.sgcarmart.com/used_cars/info.php?ID=1314002&DL=4667\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331504&DL=3989\
# https://www.sgcarmart.com/used_cars/info.php?ID=1304322&DL=4454\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334446&DL=3863\
# https://www.sgcarmart.com/used_cars/info.php?ID=1327181&DL=2097\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333723&DL=2051\
# https://www.sgcarmart.com/used_cars/info.php?ID=1324822&DL=4717\
# https://www.sgcarmart.com/used_cars/info.php?ID=1294191&DL=4364\
# https://www.sgcarmart.com/used_cars/info.php?ID=1327238&DL=1001\
# https://www.sgcarmart.com/used_cars/info.php?ID=1308726&DL=2469\
# https://www.sgcarmart.com/used_cars/info.php?ID=1299979&DL=3845\
# https://www.sgcarmart.com/used_cars/info.php?ID=1294196&DL=3587\
# https://www.sgcarmart.com/used_cars/info.php?ID=1322965&DL=2934\
# https://www.sgcarmart.com/used_cars/info.php?ID=1295698&DL=2277\
# https://www.sgcarmart.com/used_cars/info.php?ID=1285554&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1310708&DL=4239\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331277&DL=4745\
# https://www.sgcarmart.com/used_cars/info.php?ID=1124015&DL=2454\
# https://www.sgcarmart.com/used_cars/info.php?ID=1327216&DL=3024\
# https://www.sgcarmart.com/used_cars/info.php?ID=1297489&DL=1193\
# https://www.sgcarmart.com/used_cars/info.php?ID=1142711&DL=3405\
# https://www.sgcarmart.com/used_cars/info.php?ID=1295884&DL=1339\
# https://www.sgcarmart.com/used_cars/info.php?ID=1327958&DL=1136\
# https://www.sgcarmart.com/used_cars/info.php?ID=1154738&DL=1300\
# https://www.sgcarmart.com/used_cars/info.php?ID=1312980&DL=2080\
# https://www.sgcarmart.com/used_cars/info.php?ID=1321233&DL=2626\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334218&DL=1127\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333620&DL=4717\
# https://www.sgcarmart.com/used_cars/info.php?ID=1315174&DL=3968\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331635&DL=1127\
# https://www.sgcarmart.com/used_cars/info.php?ID=1311249&DL=2029\
# https://www.sgcarmart.com/used_cars/info.php?ID=1260215&DL=2080\
# https://www.sgcarmart.com/used_cars/info.php?ID=1321428&DL=3730\
# https://www.sgcarmart.com/used_cars/info.php?ID=1311245&DL=2139\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334315&DL=2244\
# https://www.sgcarmart.com/used_cars/info.php?ID=1327675&DL=3333\
# https://www.sgcarmart.com/used_cars/info.php?ID=1318764&DL=4055\
# https://www.sgcarmart.com/used_cars/info.php?ID=1319796&DL=3900\
# https://www.sgcarmart.com/used_cars/info.php?ID=1311225&DL=4508\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330467&DL=3426\
# https://www.sgcarmart.com/used_cars/info.php?ID=1271223&DL=2913\
# https://www.sgcarmart.com/used_cars/info.php?ID=1327213&DL=4500\
# https://www.sgcarmart.com/used_cars/info.php?ID=1328644&DL=4343\
# https://www.sgcarmart.com/used_cars/info.php?ID=1329863&DL=3730\
# https://www.sgcarmart.com/used_cars/info.php?ID=1307570&DL=2080\
# https://www.sgcarmart.com/used_cars/info.php?ID=1312792&DL=3037\
# https://www.sgcarmart.com/used_cars/info.php?ID=1315936&DL=2976\
# https://www.sgcarmart.com/used_cars/info.php?ID=1295736&DL=3800\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333293&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330581&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1327144&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332296&DL=1079\
# https://www.sgcarmart.com/used_cars/info.php?ID=1287747&DL=2984\
# https://www.sgcarmart.com/used_cars/info.php?ID=1256729&DL=4554\
# https://www.sgcarmart.com/used_cars/info.php?ID=1300588&DL=4427\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332902&DL=3271\
# https://www.sgcarmart.com/used_cars/info.php?ID=1327538&DL=4031\
# https://www.sgcarmart.com/used_cars/info.php?ID=1292694&DL=4037\
# https://www.sgcarmart.com/used_cars/info.php?ID=1274887&DL=4075\
# https://www.sgcarmart.com/used_cars/info.php?ID=1327471&DL=3730\
# https://www.sgcarmart.com/used_cars/info.php?ID=1322714&DL=3451\
# https://www.sgcarmart.com/used_cars/info.php?ID=1327444&DL=3137\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332602&DL=1400\
# https://www.sgcarmart.com/used_cars/info.php?ID=1315402&DL=3446\
# https://www.sgcarmart.com/used_cars/info.php?ID=1320612&DL=3079\
# https://www.sgcarmart.com/used_cars/info.php?ID=1314519&DL=3545\
# https://www.sgcarmart.com/used_cars/info.php?ID=1318785&DL=4599\
# https://www.sgcarmart.com/used_cars/info.php?ID=1321394&DL=4727\
# https://www.sgcarmart.com/used_cars/info.php?ID=1321142&DL=3393\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333524&DL=4277\
# https://www.sgcarmart.com/used_cars/info.php?ID=1308618&DL=3133\
# https://www.sgcarmart.com/used_cars/info.php?ID=1322953&DL=3900\
# https://www.sgcarmart.com/used_cars/info.php?ID=1298971&DL=2969\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330832&DL=1024\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331214&DL=4239\
# https://www.sgcarmart.com/used_cars/info.php?ID=1257275&DL=3975\
# https://www.sgcarmart.com/used_cars/info.php?ID=1319488&DL=1353\
# https://www.sgcarmart.com/used_cars/info.php?ID=1276495&DL=4508\
# https://www.sgcarmart.com/used_cars/info.php?ID=1091854&DL=2695\
# https://www.sgcarmart.com/used_cars/info.php?ID=1326712&DL=2875\
# https://www.sgcarmart.com/used_cars/info.php?ID=1323591&DL=2189\
# https://www.sgcarmart.com/used_cars/info.php?ID=1320140&DL=1001\
# https://www.sgcarmart.com/used_cars/info.php?ID=1240392&DL=3794\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331588&DL=2944\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331812&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334386&DL=1213\
# https://www.sgcarmart.com/used_cars/info.php?ID=1329352&DL=3034\
# https://www.sgcarmart.com/used_cars/info.php?ID=1328323&DL=4405\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330755&DL=1001\
# https://www.sgcarmart.com/used_cars/info.php?ID=1320722&DL=2725\
# https://www.sgcarmart.com/used_cars/info.php?ID=1312325&DL=3137\
# https://www.sgcarmart.com/used_cars/info.php?ID=1307396&DL=3048\
# https://www.sgcarmart.com/used_cars/info.php?ID=1301187&DL=1095\
# https://www.sgcarmart.com/used_cars/info.php?ID=1327630&DL=1240\
# https://www.sgcarmart.com/used_cars/info.php?ID=1314895&DL=2080\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332953&DL=3381\
# https://www.sgcarmart.com/used_cars/info.php?ID=1286628&DL=3931\
# https://www.sgcarmart.com/used_cars/info.php?ID=1163811&DL=3405\
# https://www.sgcarmart.com/used_cars/info.php?ID=1313119&DL=3100\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333971&DL=4396\
# https://www.sgcarmart.com/used_cars/info.php?ID=1306339&DL=1032\
# https://www.sgcarmart.com/used_cars/info.php?ID=1317585&DL=3452\
# https://www.sgcarmart.com/used_cars/info.php?ID=1320320&DL=4427\
# https://www.sgcarmart.com/used_cars/info.php?ID=1236268&DL=3047\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331817&DL=2097\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331431&DL=4189\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333062&DL=3892\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331136&DL=2725\
# https://www.sgcarmart.com/used_cars/info.php?ID=1321578&DL=4647\
# https://www.sgcarmart.com/used_cars/info.php?ID=1328552&DL=4030\
# https://www.sgcarmart.com/used_cars/info.php?ID=1255594&DL=3468\
# https://www.sgcarmart.com/used_cars/info.php?ID=1316415&DL=1195\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335007&DL=3381\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330661&DL=1354\
# https://www.sgcarmart.com/used_cars/info.php?ID=1329433&DL=4355\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332353&DL=2659\
# https://www.sgcarmart.com/used_cars/info.php?ID=1304841&DL=3382\
# https://www.sgcarmart.com/used_cars/info.php?ID=1316574&DL=2757\
# https://www.sgcarmart.com/used_cars/info.php?ID=1272277&DL=8008\
# https://www.sgcarmart.com/used_cars/info.php?ID=1307997&DL=2029\
# https://www.sgcarmart.com/used_cars/info.php?ID=1329265&DL=4332\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330848&DL=3597\
# https://www.sgcarmart.com/used_cars/info.php?ID=1276021&DL=3841\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332747&DL=4108\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334899&DL=2849\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332175&DL=2201\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333638&DL=3426\
# https://www.sgcarmart.com/used_cars/info.php?ID=1292138&DL=3118\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334211&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1303050&DL=3163\
# https://www.sgcarmart.com/used_cars/info.php?ID=1222048&DL=3451\
# https://www.sgcarmart.com/used_cars/info.php?ID=1319176&DL=3214\
# https://www.sgcarmart.com/used_cars/info.php?ID=1321047&DL=3730\
# https://www.sgcarmart.com/used_cars/info.php?ID=1275515&DL=4442\
# https://www.sgcarmart.com/used_cars/info.php?ID=1291367&DL=4659\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332153&DL=3627\
# https://www.sgcarmart.com/used_cars/info.php?ID=1197004&DL=3382\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333238&DL=4032\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334448&DL=4461\
# https://www.sgcarmart.com/used_cars/info.php?ID=1243322&DL=3541\
# https://www.sgcarmart.com/used_cars/info.php?ID=1305895&DL=3426\
# https://www.sgcarmart.com/used_cars/info.php?ID=1306304&DL=2473\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332844&DL=3359\
# https://www.sgcarmart.com/used_cars/info.php?ID=1328914&DL=4398\
# https://www.sgcarmart.com/used_cars/info.php?ID=1327370&DL=3647\
# https://www.sgcarmart.com/used_cars/info.php?ID=1328161&DL=1079\
# https://www.sgcarmart.com/used_cars/info.php?ID=1325824&DL=2332\
# https://www.sgcarmart.com/used_cars/info.php?ID=1292020&DL=3989\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332154&DL=3271\
# https://www.sgcarmart.com/used_cars/info.php?ID=1309964&DL=2701\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330972&DL=4694\
# https://www.sgcarmart.com/used_cars/info.php?ID=1315280&DL=2792\
# https://www.sgcarmart.com/used_cars/info.php?ID=1269357&DL=3961\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332837&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1271440&DL=2244\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330219&DL=1107\
# https://www.sgcarmart.com/used_cars/info.php?ID=1322195&DL=1073\
# https://www.sgcarmart.com/used_cars/info.php?ID=1316616&DL=1309\
# https://www.sgcarmart.com/used_cars/info.php?ID=1237629&DL=3607\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332217&DL=3318\
# https://www.sgcarmart.com/used_cars/info.php?ID=1296482&DL=4731\
# https://www.sgcarmart.com/used_cars/info.php?ID=1134004&DL=3892\
# https://www.sgcarmart.com/used_cars/info.php?ID=1255204&DL=2198\
# https://www.sgcarmart.com/used_cars/info.php?ID=1272538&DL=2029\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330870&DL=3214\
# https://www.sgcarmart.com/used_cars/info.php?ID=1327586&DL=3849\
# https://www.sgcarmart.com/used_cars/info.php?ID=1318393&DL=2984\
# https://www.sgcarmart.com/used_cars/info.php?ID=1265365&DL=3647\
# https://www.sgcarmart.com/used_cars/info.php?ID=1308958&DL=3902\
# https://www.sgcarmart.com/used_cars/info.php?ID=1200724&DL=1034\
# https://www.sgcarmart.com/used_cars/info.php?ID=1293121&DL=4355\
# https://www.sgcarmart.com/used_cars/info.php?ID=1236097&DL=3924\
# https://www.sgcarmart.com/used_cars/info.php?ID=1292113&DL=4189\
# https://www.sgcarmart.com/used_cars/info.php?ID=1324106&DL=1024\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333226&DL=1311\
# https://www.sgcarmart.com/used_cars/info.php?ID=1208931&DL=2175\
# https://www.sgcarmart.com/used_cars/info.php?ID=1323398&DL=1047\
# https://www.sgcarmart.com/used_cars/info.php?ID=1318223&DL=3564\
# https://www.sgcarmart.com/used_cars/info.php?ID=1278517&DL=2349\
# https://www.sgcarmart.com/used_cars/info.php?ID=1324245&DL=4465\
# https://www.sgcarmart.com/used_cars/info.php?ID=1308428&DL=3426\
# https://www.sgcarmart.com/used_cars/info.php?ID=1327279&DL=2011\
# https://www.sgcarmart.com/used_cars/info.php?ID=1326133&DL=4031\
# https://www.sgcarmart.com/used_cars/info.php?ID=1302626&DL=4332\
# https://www.sgcarmart.com/used_cars/info.php?ID=1323326&DL=4332\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332410&DL=2885\
# https://www.sgcarmart.com/used_cars/info.php?ID=1223991&DL=3350\
# https://www.sgcarmart.com/used_cars/info.php?ID=1327885&DL=2870\
# https://www.sgcarmart.com/used_cars/info.php?ID=1314845&DL=2189\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331159&DL=4635\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331202&DL=3142\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334841&DL=3546\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333944&DL=2029\
# https://www.sgcarmart.com/used_cars/info.php?ID=1255145&DL=3754\
# https://www.sgcarmart.com/used_cars/info.php?ID=1328399&DL=2175\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331643&DL=2025\
# https://www.sgcarmart.com/used_cars/info.php?ID=1314868&DL=3597\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331488&DL=4494\
# https://www.sgcarmart.com/used_cars/info.php?ID=1323805&DL=3700\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334007&DL=3934\
# https://www.sgcarmart.com/used_cars/info.php?ID=1194595&DL=2096\
# https://www.sgcarmart.com/used_cars/info.php?ID=1313450&DL=2277\
# https://www.sgcarmart.com/used_cars/info.php?ID=1310946&DL=3175\
# https://www.sgcarmart.com/used_cars/info.php?ID=1325863&DL=3730\
# https://www.sgcarmart.com/used_cars/info.php?ID=1313628&DL=2014\
# https://www.sgcarmart.com/used_cars/info.php?ID=1314808&DL=2341\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334855&DL=4449\
# https://www.sgcarmart.com/used_cars/info.php?ID=1262598&DL=8008\
# https://www.sgcarmart.com/used_cars/info.php?ID=1249360&DL=2469\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330944&DL=2689\
# https://www.sgcarmart.com/used_cars/info.php?ID=1292778&DL=2469\
# https://www.sgcarmart.com/used_cars/info.php?ID=1267998&DL=8008\
# https://www.sgcarmart.com/used_cars/info.php?ID=1291898&DL=3037\
# https://www.sgcarmart.com/used_cars/info.php?ID=1231078&DL=3359\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334474&DL=1047\
# https://www.sgcarmart.com/used_cars/info.php?ID=1325274&DL=2029\
# https://www.sgcarmart.com/used_cars/info.php?ID=1298876&DL=2128\
# https://www.sgcarmart.com/used_cars/info.php?ID=1315870&DL=3541
# https://www.sgcarmart.com/used_cars/info.php?ID=1319077&DL=4352\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332653&DL=3573\
# https://www.sgcarmart.com/used_cars/info.php?ID=1303848&DL=2080\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331655&DL=2875\
# https://www.sgcarmart.com/used_cars/info.php?ID=1325178&DL=4645\
# https://www.sgcarmart.com/used_cars/info.php?ID=1292664&DL=2397\
# https://www.sgcarmart.com/used_cars/info.php?ID=1313328&DL=2080\
# https://www.sgcarmart.com/used_cars/info.php?ID=1272077&DL=4573\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333065&DL=8008\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331723&DL=2549\
# https://www.sgcarmart.com/used_cars/info.php?ID=1284789&DL=3989\
# https://www.sgcarmart.com/used_cars/info.php?ID=1266986&DL=8008\
# https://www.sgcarmart.com/used_cars/info.php?ID=1317537&DL=3137\
# https://www.sgcarmart.com/used_cars/info.php?ID=1322799&DL=1309\
# https://www.sgcarmart.com/used_cars/info.php?ID=1294239&DL=2797\
# https://www.sgcarmart.com/used_cars/info.php?ID=1329043&DL=4140\
# https://www.sgcarmart.com/used_cars/info.php?ID=1306229&DL=1194\
# https://www.sgcarmart.com/used_cars/info.php?ID=1278168&DL=1103\
# https://www.sgcarmart.com/used_cars/info.php?ID=1307687&DL=4517\
# https://www.sgcarmart.com/used_cars/info.php?ID=1057733&DL=1188\
# https://www.sgcarmart.com/used_cars/info.php?ID=1267590&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331218&DL=2954\
# https://www.sgcarmart.com/used_cars/info.php?ID=1320498&DL=2349\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330214&DL=1107\
# https://www.sgcarmart.com/used_cars/info.php?ID=1294031&DL=3283\
# https://www.sgcarmart.com/used_cars/info.php?ID=1323676&DL=3811\
# https://www.sgcarmart.com/used_cars/info.php?ID=1320961&DL=3381\
# https://www.sgcarmart.com/used_cars/info.php?ID=1327678&DL=3456\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333985&DL=3749\
# https://www.sgcarmart.com/used_cars/info.php?ID=1302326&DL=3283\
# https://www.sgcarmart.com/used_cars/info.php?ID=1328880&DL=1213\
# https://www.sgcarmart.com/used_cars/info.php?ID=1208107&DL=2469\
# https://www.sgcarmart.com/used_cars/info.php?ID=1322266&DL=4453\
# https://www.sgcarmart.com/used_cars/info.php?ID=1299408&DL=2352\
# https://www.sgcarmart.com/used_cars/info.php?ID=1238559&DL=3093\
# https://www.sgcarmart.com/used_cars/info.php?ID=1292713&DL=4419\
# https://www.sgcarmart.com/used_cars/info.php?ID=1286731&DL=4239\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332843&DL=4508\
# https://www.sgcarmart.com/used_cars/info.php?ID=1299524&DL=2448\
# https://www.sgcarmart.com/used_cars/info.php?ID=1323032&DL=3794\
# https://www.sgcarmart.com/used_cars/info.php?ID=1244209&DL=
# https://www.sgcarmart.com/used_cars/info.php?ID=1324316&DL=4277\
# https://www.sgcarmart.com/used_cars/info.php?ID=1295553&DL=1032\
# https://www.sgcarmart.com/used_cars/info.php?ID=1218109&DL=3875\
# https://www.sgcarmart.com/used_cars/info.php?ID=1284863&DL=2030\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333639&DL=1238\
# https://www.sgcarmart.com/used_cars/info.php?ID=1183042&DL=4074\
# https://www.sgcarmart.com/used_cars/info.php?ID=1297334&DL=3382\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331497&DL=2014\
# https://www.sgcarmart.com/used_cars/info.php?ID=1295654&DL=2454\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332436&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1257318&DL=4427\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331762&DL=3321\
# https://www.sgcarmart.com/used_cars/info.php?ID=1326863&DL=3037\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334763&DL=4694\
# https://www.sgcarmart.com/used_cars/info.php?ID=1310975&DL=3418\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332575&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1272846&DL=3414\
# https://www.sgcarmart.com/used_cars/info.php?ID=1309019&DL=2650\
# https://www.sgcarmart.com/used_cars/info.php?ID=1297028&DL=3541\
# https://www.sgcarmart.com/used_cars/info.php?ID=1319090&DL=2870\
# https://www.sgcarmart.com/used_cars/info.php?ID=1314290&DL=3426\
# https://www.sgcarmart.com/used_cars/info.php?ID=1323970&DL=3426\
# https://www.sgcarmart.com/used_cars/info.php?ID=1323842&DL=2469\
# https://www.sgcarmart.com/used_cars/info.php?ID=1298884&DL=2296\
# https://www.sgcarmart.com/used_cars/info.php?ID=1325429&DL=4688\
# https://www.sgcarmart.com/used_cars/info.php?ID=1298854&DL=3743\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334656&DL=1152\
# https://www.sgcarmart.com/used_cars/info.php?ID=1218609&DL=4419\
# https://www.sgcarmart.com/used_cars/info.php?ID=1295291&DL=4508\
# https://www.sgcarmart.com/used_cars/info.php?ID=1298739&DL=1020\
# https://www.sgcarmart.com/used_cars/info.php?ID=1259034&DL=2029\
# https://www.sgcarmart.com/used_cars/info.php?ID=1245088&DL=3647\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330485&DL=4727\
# https://www.sgcarmart.com/used_cars/info.php?ID=1327904&DL=1028\
# https://www.sgcarmart.com/used_cars/info.php?ID=1302387&DL=4457\
# https://www.sgcarmart.com/used_cars/info.php?ID=1305967&DL=1070\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333287&DL=4412\
# https://www.sgcarmart.com/used_cars/info.php?ID=1320359&DL=3456\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332496&DL=3476\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330787&DL=4412\
# https://www.sgcarmart.com/used_cars/info.php?ID=1305158&DL=2875\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330584&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1310855&DL=3597\
# https://www.sgcarmart.com/used_cars/info.php?ID=1312128&DL=4327\
# https://www.sgcarmart.com/used_cars/info.php?ID=1265453&DL=2875\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334848&DL=1245\
# https://www.sgcarmart.com/used_cars/info.php?ID=1304127&DL=2217\
# https://www.sgcarmart.com/used_cars/info.php?ID=1306206&DL=3541\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332484&DL=3801\
# https://www.sgcarmart.com/used_cars/info.php?ID=1317962&DL=2984\
# https://www.sgcarmart.com/used_cars/info.php?ID=1248840&DL=2296\
# https://www.sgcarmart.com/used_cars/info.php?ID=1318189&DL=3381\
# https://www.sgcarmart.com/used_cars/info.php?ID=1329728&DL=3350\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330842&DL=3616\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331115&DL=4108\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331534&DL=3368\
# https://www.sgcarmart.com/used_cars/info.php?ID=1325360&DL=2351\
# https://www.sgcarmart.com/used_cars/info.php?ID=1323686&DL=2080\
# https://www.sgcarmart.com/used_cars/info.php?ID=1325221&DL=1397\
# https://www.sgcarmart.com/used_cars/info.php?ID=1305100&DL=2011\
# https://www.sgcarmart.com/used_cars/info.php?ID=1317867&DL=3626\
# https://www.sgcarmart.com/used_cars/info.php?ID=1318394&DL=2140\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331523&DL=4668\
# https://www.sgcarmart.com/used_cars/info.php?ID=1257340&DL=3321\
# https://www.sgcarmart.com/used_cars/info.php?ID=1316263&DL=1111\
# https://www.sgcarmart.com/used_cars/info.php?ID=1326949&DL=4412\
# https://www.sgcarmart.com/used_cars/info.php?ID=1318321&DL=4604\
# https://www.sgcarmart.com/used_cars/info.php?ID=1285364&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1290332&DL=3811\
# https://www.sgcarmart.com/used_cars/info.php?ID=1183740&DL=1337\
# https://www.sgcarmart.com/used_cars/info.php?ID=1321625&DL=2416\
# https://www.sgcarmart.com/used_cars/info.php?ID=1311212&DL=3851\
# https://www.sgcarmart.com/used_cars/info.php?ID=1288648&DL=1155\
# https://www.sgcarmart.com/used_cars/info.php?ID=1317583&DL=2626\
# https://www.sgcarmart.com/used_cars/info.php?ID=1242206&DL=3318\
# https://www.sgcarmart.com/used_cars/info.php?ID=1311043&DL=4404\
# https://www.sgcarmart.com/used_cars/info.php?ID=1076319&DL=3837\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331502&DL=3573\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334362&DL=4717\
# https://www.sgcarmart.com/used_cars/info.php?ID=1296442&DL=3337\
# https://www.sgcarmart.com/used_cars/info.php?ID=1295207&DL=1193\
# https://www.sgcarmart.com/used_cars/info.php?ID=1306638&DL=1238\
# https://www.sgcarmart.com/used_cars/info.php?ID=1325633&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330290&DL=2080\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333567&DL=4189\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331747&DL=3100\
# https://www.sgcarmart.com/used_cars/info.php?ID=1322347&DL=2291\
# https://www.sgcarmart.com/used_cars/info.php?ID=1299081&DL=4228\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332503&DL=3359\
# https://www.sgcarmart.com/used_cars/info.php?ID=1325570&DL=3700\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331595&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334728&DL=3607\
# https://www.sgcarmart.com/used_cars/info.php?ID=1279315&DL=4332\
# https://www.sgcarmart.com/used_cars/info.php?ID=1298105&DL=1135\
# https://www.sgcarmart.com/used_cars/info.php?ID=1266267&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1325871&DL=2189\
# https://www.sgcarmart.com/used_cars/info.php?ID=1322941&DL=1111\
# https://www.sgcarmart.com/used_cars/info.php?ID=1240047&DL=3414\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332566&DL=2428\
# https://www.sgcarmart.com/used_cars/info.php?ID=1149441&DL=3175\
# https://www.sgcarmart.com/used_cars/info.php?ID=1294962&DL=3318\
# https://www.sgcarmart.com/used_cars/info.php?ID=1316323&DL=2097\
# https://www.sgcarmart.com/used_cars/info.php?ID=1299086&DL=4612\
# https://www.sgcarmart.com/used_cars/info.php?ID=1329825&DL=3048\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334328&DL=1269\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334237&DL=2953\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331112&DL=1044\
# https://www.sgcarmart.com/used_cars/info.php?ID=1328472&DL=1127\
# https://www.sgcarmart.com/used_cars/info.php?ID=1257286&DL=3850\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332727&DL=4108\
# https://www.sgcarmart.com/used_cars/info.php?ID=1281919&DL=3722\
# https://www.sgcarmart.com/used_cars/info.php?ID=1327075&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332157&DL=4219\
# https://www.sgcarmart.com/used_cars/info.php?ID=1301468&DL=2097\
# https://www.sgcarmart.com/used_cars/info.php?ID=1312234&DL=3993\
# https://www.sgcarmart.com/used_cars/info.php?ID=1246413&DL=2754\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331333&DL=3160\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334534&DL=4131\
# https://www.sgcarmart.com/used_cars/info.php?ID=1324474&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331981&DL=4352\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332334&DL=3546\
# https://www.sgcarmart.com/used_cars/info.php?ID=1325576&DL=2793\
# https://www.sgcarmart.com/used_cars/info.php?ID=1315730&DL=4412\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333488&DL=3722\
# https://www.sgcarmart.com/used_cars/info.php?ID=1301913&DL=3283\
# https://www.sgcarmart.com/used_cars/info.php?ID=1321513&DL=1106\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334475&DL=4398\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330489&DL=2351\
# https://www.sgcarmart.com/used_cars/info.php?ID=1307327&DL=3759\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331701&DL=3911\
# https://www.sgcarmart.com/used_cars/info.php?ID=1329456&DL=3163\
# https://www.sgcarmart.com/used_cars/info.php?ID=1273194&DL=3301\
# https://www.sgcarmart.com/used_cars/info.php?ID=1280191&DL=2469\
# https://www.sgcarmart.com/used_cars/info.php?ID=1320958&DL=2707\
# https://www.sgcarmart.com/used_cars/info.php?ID=1325558&DL=3759\
# https://www.sgcarmart.com/used_cars/info.php?ID=1267914&DL=3954\
# https://www.sgcarmart.com/used_cars/info.php?ID=1251611&DL=3507\
# https://www.sgcarmart.com/used_cars/info.php?ID=1319927&DL=3283\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331181&DL=3887\
# https://www.sgcarmart.com/used_cars/info.php?ID=1328252&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1324426&DL=4464\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334607&DL=2296\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331096&DL=4413\
# https://www.sgcarmart.com/used_cars/info.php?ID=1321766&DL=4648\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333202&DL=4745\
# https://www.sgcarmart.com/used_cars/info.php?ID=1238961&DL=4380\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330636&DL=4030\
# https://www.sgcarmart.com/used_cars/info.php?ID=1313593&DL=4670\
# https://www.sgcarmart.com/used_cars/info.php?ID=1324255&DL=1026\
# https://www.sgcarmart.com/used_cars/info.php?ID=1324705&DL=2969&utm_content=SLeligible\
# https://www.sgcarmart.com/used_cars/info.php?ID=1308589&DL=3468\
# https://www.sgcarmart.com/used_cars/info.php?ID=1325488&DL=2341\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332891&DL=4254\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332367&DL=4166\
# https://www.sgcarmart.com/used_cars/info.php?ID=1264348&DL=4102\
# https://www.sgcarmart.com/used_cars/info.php?ID=1289380&DL=8008\
# https://www.sgcarmart.com/used_cars/info.php?ID=1307781&DL=2689\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334843&DL=1245\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330827&DL=3034\
# https://www.sgcarmart.com/used_cars/info.php?ID=1185352&DL=3811\
# https://www.sgcarmart.com/used_cars/info.php?ID=1309511&DL=4309\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331705&DL=3911\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334003&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332529&DL=4555\
# https://www.sgcarmart.com/used_cars/info.php?ID=1325854&DL=3648\
# https://www.sgcarmart.com/used_cars/info.php?ID=1329530&DL=3283\
# https://www.sgcarmart.com/used_cars/info.php?ID=1321151&DL=3405\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334330&DL=2849\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330850&DL=3597\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330410&DL=3759\
# https://www.sgcarmart.com/used_cars/info.php?ID=1314769&DL=3283\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333498&DL=3647\
# https://www.sgcarmart.com/used_cars/info.php?ID=1329423&DL=3642\
# https://www.sgcarmart.com/used_cars/info.php?ID=1311228&DL=3116\
# https://www.sgcarmart.com/used_cars/info.php?ID=1310434&DL=2976\
# https://www.sgcarmart.com/used_cars/info.php?ID=1316925&DL=3024\
# https://www.sgcarmart.com/used_cars/info.php?ID=1320995&DL=1240\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333044&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1322895&DL=4630\
# https://www.sgcarmart.com/used_cars/info.php?ID=1321339&DL=3570\
# https://www.sgcarmart.com/used_cars/info.php?ID=1310848&DL=3597\
# https://www.sgcarmart.com/used_cars/info.php?ID=1320356&DL=2793\
# https://www.sgcarmart.com/used_cars/info.php?ID=1237442&DL=1277\
# https://www.sgcarmart.com/used_cars/info.php?ID=1308251&DL=4481\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334525&DL=4635\
# https://www.sgcarmart.com/used_cars/info.php?ID=1240816&DL=3214\
# https://www.sgcarmart.com/used_cars/info.php?ID=1274550&DL=2469\
# https://www.sgcarmart.com/used_cars/info.php?ID=1321023&DL=3730\
# https://www.sgcarmart.com/used_cars/info.php?ID=1262849&DL=2849\
# https://www.sgcarmart.com/used_cars/info.php?ID=1303879&DL=3305\
# https://www.sgcarmart.com/used_cars/info.php?ID=1323491&DL=1028\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330690&DL=2393\
# https://www.sgcarmart.com/used_cars/info.php?ID=1321882&DL=1043\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332200&DL=4239\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333989&DL=3931\
# https://www.sgcarmart.com/used_cars/info.php?ID=1324695&DL=4500\
# https://www.sgcarmart.com/used_cars/info.php?ID=1181739&DL=1005\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332548&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1293070&DL=3426\
# https://www.sgcarmart.com/used_cars/info.php?ID=1307786&DL=4234\
# https://www.sgcarmart.com/used_cars/info.php?ID=1326045&DL=2984\
# https://www.sgcarmart.com/used_cars/info.php?ID=1278486&DL=2793\
# https://www.sgcarmart.com/used_cars/info.php?ID=1319743&DL=1001\
# https://www.sgcarmart.com/used_cars/info.php?ID=1298413&DL=3648\
# https://www.sgcarmart.com/used_cars/info.php?ID=1313081&DL=3647\
# https://www.sgcarmart.com/used_cars/info.php?ID=1249324&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1305366&DL=3743\
# https://www.sgcarmart.com/used_cars/info.php?ID=1315498&DL=2291\
# https://www.sgcarmart.com/used_cars/info.php?ID=1327603&DL=2080\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331891&DL=4147\
# https://www.sgcarmart.com/used_cars/info.php?ID=1183132&DL=4386\
# https://www.sgcarmart.com/used_cars/info.php?ID=1325946&DL=8008\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332057&DL=4412\
# https://www.sgcarmart.com/used_cars/info.php?ID=1306865&DL=3175\
# https://www.sgcarmart.com/used_cars/info.php?ID=1307724&DL=3079\
# https://www.sgcarmart.com/used_cars/info.php?ID=1327900&DL=3792\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334359&DL=3597\
# https://www.sgcarmart.com/used_cars/info.php?ID=1327716&DL=1269\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334314&DL=2296\
# https://www.sgcarmart.com/used_cars/info.php?ID=1323449&DL=1090\
# https://www.sgcarmart.com/used_cars/info.php?ID=1329562&DL=2454\
# https://www.sgcarmart.com/used_cars/info.php?ID=1219330&DL=4449\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330641&DL=2757\
# https://www.sgcarmart.com/used_cars/info.php?ID=1327703&DL=1044\
# https://www.sgcarmart.com/used_cars/info.php?ID=1251317&DL=2296\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330017&DL=4031\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332022&DL=4219\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332204&DL=4239\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333644&DL=2283\
# https://www.sgcarmart.com/used_cars/info.php?ID=1220723&DL=3137\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334004&DL=1213\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333598&DL=2549\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333994&DL=3100\
# https://www.sgcarmart.com/used_cars/info.php?ID=1326487&DL=4003\
# https://www.sgcarmart.com/used_cars/info.php?ID=1240448&DL=3414\
# https://www.sgcarmart.com/used_cars/info.php?ID=1313707&DL=3845\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332846&DL=4108\
# https://www.sgcarmart.com/used_cars/info.php?ID=1116998&DL=1010\
# https://www.sgcarmart.com/used_cars/info.php?ID=1272487&DL=1111\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333456&DL=3321&utm_content=SLeligible\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333233&DL=1351\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334513&DL=1264\
# https://www.sgcarmart.com/used_cars/info.php?ID=1329669&DL=1194\
# https://www.sgcarmart.com/used_cars/info.php?ID=1313862&DL=3393\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332650&DL=4454\
# https://www.sgcarmart.com/used_cars/info.php?ID=1301874&DL=2754\
# https://www.sgcarmart.com/used_cars/info.php?ID=1318154&DL=2754\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330299&DL=3416\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333270&DL=3137\
# https://www.sgcarmart.com/used_cars/info.php?ID=1237401&DL=4386\
# https://www.sgcarmart.com/used_cars/info.php?ID=1190827&DL=2410\
# https://www.sgcarmart.com/used_cars/info.php?ID=1272289&DL=4594\
# https://www.sgcarmart.com/used_cars/info.php?ID=1312829&DL=4473\
# https://www.sgcarmart.com/used_cars/info.php?ID=1326456&DL=4442\
# https://www.sgcarmart.com/used_cars/info.php?ID=1327440&DL=3043\
# https://www.sgcarmart.com/used_cars/info.php?ID=1319804&DL=3164\
# https://www.sgcarmart.com/used_cars/info.php?ID=1326717&DL=2189\
# https://www.sgcarmart.com/used_cars/info.php?ID=1317678&DL=1360\
# https://www.sgcarmart.com/used_cars/info.php?ID=1278621&DL=2793\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330570&DL=3214\
# https://www.sgcarmart.com/used_cars/info.php?ID=1310141&DL=2097\
# https://www.sgcarmart.com/used_cars/info.php?ID=1289794&DL=3648\
# https://www.sgcarmart.com/used_cars/info.php?ID=1303580&DL=3282\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334066&DL=3214\
# https://www.sgcarmart.com/used_cars/info.php?ID=1321504&DL=2454\
# https://www.sgcarmart.com/used_cars/info.php?ID=1232098&DL=3968\
# https://www.sgcarmart.com/used_cars/info.php?ID=1257156&DL=2804\
# https://www.sgcarmart.com/used_cars/info.php?ID=1288205&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333519&DL=1095\
# https://www.sgcarmart.com/used_cars/info.php?ID=1267518&DL=2655\
# https://www.sgcarmart.com/used_cars/info.php?ID=1257455&DL=3989\
# https://www.sgcarmart.com/used_cars/info.php?ID=1318425&DL=2397\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333203&DL=4030\
# https://www.sgcarmart.com/used_cars/info.php?ID=1282512&DL=3037\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334393&DL=3730\
# https://www.sgcarmart.com/used_cars/info.php?ID=1313833&DL=4131\
# https://www.sgcarmart.com/used_cars/info.php?ID=1316508&DL=3283\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334094&DL=3214\
# https://www.sgcarmart.com/used_cars/info.php?ID=1295416&DL=3283\
# https://www.sgcarmart.com/used_cars/info.php?ID=1301378&DL=3043\
# https://www.sgcarmart.com/used_cars/info.php?ID=1326101&DL=4706\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332516&DL=2725\
# https://www.sgcarmart.com/used_cars/info.php?ID=1301287&DL=2984\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333435&DL=502\
# https://www.sgcarmart.com/used_cars/info.php?ID=1321622&DL=1001\
# https://www.sgcarmart.com/used_cars/info.php?ID=1321915&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1292604&DL=2245\
# https://www.sgcarmart.com/used_cars/info.php?ID=1315975&DL=3901\
# https://www.sgcarmart.com/used_cars/info.php?ID=1299496&DL=2303\
# https://www.sgcarmart.com/used_cars/info.php?ID=1325290&DL=2303\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331511&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1310952&DL=4157\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334111&DL=1001\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332074&DL=3865\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332177&DL=4413\
# https://www.sgcarmart.com/used_cars/info.php?ID=1291174&DL=1344\
# https://www.sgcarmart.com/used_cars/info.php?ID=1326265&DL=1277\
# https://www.sgcarmart.com/used_cars/info.php?ID=1280264&DL=3393\
# https://www.sgcarmart.com/used_cars/info.php?ID=1293579&DL=2469\
# https://www.sgcarmart.com/used_cars/info.php?ID=1317247&DL=4648\
# https://www.sgcarmart.com/used_cars/info.php?ID=1321406&DL=1339\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333395&DL=2469\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333021&DL=3597\
# https://www.sgcarmart.com/used_cars/info.php?ID=1233025&DL=3142\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330579&DL=3853\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333025&DL=3597\
# https://www.sgcarmart.com/used_cars/info.php?ID=1324464&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1274786&DL=2029\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333587&DL=3647\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332935&DL=1013\
# https://www.sgcarmart.com/used_cars/info.php?ID=1320361&DL=1353\
# https://www.sgcarmart.com/used_cars/info.php?ID=1310572&DL=2757\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331794&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1312241&DL=2080\
# https://www.sgcarmart.com/used_cars/info.php?ID=1313688&DL=2650\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333061&DL=4211\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332459&DL=3210\
# https://www.sgcarmart.com/used_cars/info.php?ID=1325733&DL=4239\
# https://www.sgcarmart.com/used_cars/info.php?ID=1328337&DL=2339\
# https://www.sgcarmart.com/used_cars/info.php?ID=1309900&DL=2434\
# https://www.sgcarmart.com/used_cars/info.php?ID=1326068&DL=3887\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332248&DL=4108\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332998&DL=4494\
# https://www.sgcarmart.com/used_cars/info.php?ID=1277499&DL=3954\
# https://www.sgcarmart.com/used_cars/info.php?ID=1308879&DL=4427\
# https://www.sgcarmart.com/used_cars/info.php?ID=1319478&DL=4419\
# https://www.sgcarmart.com/used_cars/info.php?ID=1299871&DL=3137\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332992&DL=3160\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332981&DL=1127\
# https://www.sgcarmart.com/used_cars/info.php?ID=1322782&DL=4648\
# https://www.sgcarmart.com/used_cars/info.php?ID=1319758&DL=1339\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334639&DL=4236\
# https://www.sgcarmart.com/used_cars/info.php?ID=1293655&DL=3518\
# https://www.sgcarmart.com/used_cars/info.php?ID=1319679&DL=2080\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332183&DL=2726\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331816&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1322120&DL=2080\
# https://www.sgcarmart.com/used_cars/info.php?ID=1308328&DL=3468\
# https://www.sgcarmart.com/used_cars/info.php?ID=1307655&DL=2341\
# https://www.sgcarmart.com/used_cars/info.php?ID=1328508&DL=2870\
# https://www.sgcarmart.com/used_cars/info.php?ID=1292733&DL=4505\
# https://www.sgcarmart.com/used_cars/info.php?ID=1328400&DL=1032\
# https://www.sgcarmart.com/used_cars/info.php?ID=1307286&DL=3863\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331253&DL=4617\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331306&DL=3597\
# https://www.sgcarmart.com/used_cars/info.php?ID=1325268&DL=2454\
# https://www.sgcarmart.com/used_cars/info.php?ID=1308049&DL=3194\
# https://www.sgcarmart.com/used_cars/info.php?ID=1241563&DL=2976\
# https://www.sgcarmart.com/used_cars/info.php?ID=1317361&DL=1195\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332467&DL=3989\
# https://www.sgcarmart.com/used_cars/info.php?ID=1310472&DL=3079\
# https://www.sgcarmart.com/used_cars/info.php?ID=1255867&DL=1028\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334284&DL=4228\
# https://www.sgcarmart.com/used_cars/info.php?ID=1320752&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330856&DL=3597\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330495&DL=3626\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334724&DL=2291\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334721&DL=2290\
# https://www.sgcarmart.com/used_cars/info.php?ID=1329696&DL=1193\
# https://www.sgcarmart.com/used_cars/info.php?ID=1318289&DL=3900\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331417&DL=3475\
# https://www.sgcarmart.com/used_cars/info.php?ID=1327157&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333402&DL=1106\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333254&DL=4391\
# https://www.sgcarmart.com/used_cars/info.php?ID=1305260&DL=2849\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334873&DL=3037\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334551&DL=3283\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331821&DL=4705\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334554&DL=3043\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331748&DL=3476\
# https://www.sgcarmart.com/used_cars/info.php?ID=1310587&DL=3894\
# https://www.sgcarmart.com/used_cars/info.php?ID=1318851&DL=1135\
# https://www.sgcarmart.com/used_cars/info.php?ID=1324618&DL=3113\
# https://www.sgcarmart.com/used_cars/info.php?ID=1291727&DL=3142\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334526&DL=4346\
# https://www.sgcarmart.com/used_cars/info.php?ID=1295431&DL=3954\
# ...
# https://www.sgcarmart.com/used_cars/info.php?ID=1319420&DL=1149\
# https://www.sgcarmart.com/used_cars/info.php?ID=1297009&DL=2984\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332105&DL=4412\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333494&DL=3590\
# https://www.sgcarmart.com/used_cars/info.php?ID=1303786&DL=1106\
# https://www.sgcarmart.com/used_cars/info.php?ID=1321237&DL=1240\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330628&DL=1026\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333186&DL=2549\
# https://www.sgcarmart.com/used_cars/info.php?ID=1326896&DL=3757\
# https://www.sgcarmart.com/used_cars/info.php?ID=1310374&DL=2793\
# https://www.sgcarmart.com/used_cars/info.php?ID=1324502&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1317219&DL=1360\
# https://www.sgcarmart.com/used_cars/info.php?ID=1303850&DL=4091\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333962&DL=1238\
# https://www.sgcarmart.com/used_cars/info.php?ID=1224922&DL=2008\
# https://www.sgcarmart.com/used_cars/info.php?ID=1234142&DL=3647\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330625&DL=3079\
# https://www.sgcarmart.com/used_cars/info.php?ID=1328780&DL=2163\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334484&DL=4263\
# https://www.sgcarmart.com/used_cars/info.php?ID=1328624&DL=1213\
# https://www.sgcarmart.com/used_cars/info.php?ID=1237687&DL=2318\
# https://www.sgcarmart.com/used_cars/info.php?ID=1287649&DL=3951\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332083&DL=3003\
# https://www.sgcarmart.com/used_cars/info.php?ID=1317265&DL=3750\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331071&DL=3989\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331338&DL=3597\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331641&DL=1418\
# https://www.sgcarmart.com/used_cars/info.php?ID=1299354&DL=3845\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333075&DL=3271\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333002&DL=4413\
# https://www.sgcarmart.com/used_cars/info.php?ID=1314597&DL=4559\
# https://www.sgcarmart.com/used_cars/info.php?ID=1313497&DL=4645\
# https://www.sgcarmart.com/used_cars/info.php?ID=1321596&DL=2976\
# https://www.sgcarmart.com/used_cars/info.php?ID=1329363&DL=1193\
# https://www.sgcarmart.com/used_cars/info.php?ID=1308131&DL=3534\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334614&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1311471&DL=2870\
# https://www.sgcarmart.com/used_cars/info.php?ID=1291769&DL=2563\
# https://www.sgcarmart.com/used_cars/info.php?ID=1246272&DL=3271\
# https://www.sgcarmart.com/used_cars/info.php?ID=1322118&DL=1064\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330083&DL=3507\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333885&DL=4609\
# https://www.sgcarmart.com/used_cars/info.php?ID=1325359&DL=1240\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331603&DL=1368\
# https://www.sgcarmart.com/used_cars/info.php?ID=1328501&DL=4743\
# https://www.sgcarmart.com/used_cars/info.php?ID=1098442&DL=3507\
# https://www.sgcarmart.com/used_cars/info.php?ID=1293042&DL=3392\
# https://www.sgcarmart.com/used_cars/info.php?ID=1287877&DL=3137\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330669&DL=4189\
# https://www.sgcarmart.com/used_cars/info.php?ID=1174170&DL=2707\
# https://www.sgcarmart.com/used_cars/info.php?ID=1240523&DL=2976\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330583&DL=4343\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330490&DL=2341\
# https://www.sgcarmart.com/used_cars/info.php?ID=1309695&DL=3100\
# https://www.sgcarmart.com/used_cars/info.php?ID=1314865&DL=3359\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331270&DL=1090\
# https://www.sgcarmart.com/used_cars/info.php?ID=1184700&DL=2493\
# https://www.sgcarmart.com/used_cars/info.php?ID=1259725&DL=2649\
# https://www.sgcarmart.com/used_cars/info.php?ID=1321746&DL=4055\
# https://www.sgcarmart.com/used_cars/info.php?ID=1312243&DL=1418\
# https://www.sgcarmart.com/used_cars/info.php?ID=1319257&DL=4031\
# https://www.sgcarmart.com/used_cars/info.php?ID=1293657&DL=3100\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334611&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1301949&DL=3495\
# https://www.sgcarmart.com/used_cars/info.php?ID=1310929&DL=4454\
# https://www.sgcarmart.com/used_cars/info.php?ID=1329760&DL=2875\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333834&DL=4168\
# https://www.sgcarmart.com/used_cars/info.php?ID=1326695&DL=3811\
# https://www.sgcarmart.com/used_cars/info.php?ID=1303952&DL=3451\
# https://www.sgcarmart.com/used_cars/info.php?ID=1299715&DL=4670\
# https://www.sgcarmart.com/used_cars/info.php?ID=1284829&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1318887&DL=4337\
# https://www.sgcarmart.com/used_cars/info.php?ID=1325267&DL=3984\
# https://www.sgcarmart.com/used_cars/info.php?ID=1324199&DL=1228\
# https://www.sgcarmart.com/used_cars/info.php?ID=1315821&DL=3433\
# https://www.sgcarmart.com/used_cars/info.php?ID=1241121&DL=1106\
# https://www.sgcarmart.com/used_cars/info.php?ID=1325954&DL=4508\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334485&DL=3283\
# https://www.sgcarmart.com/used_cars/info.php?ID=1301574&DL=1353\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333295&DL=2775\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331727&DL=3863\
# https://www.sgcarmart.com/used_cars/info.php?ID=1328827&DL=3845\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332695&DL=4405\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331323&DL=4454\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333182&DL=3758\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333457&DL=4648\
# https://www.sgcarmart.com/used_cars/info.php?ID=1324284&DL=3792\
# https://www.sgcarmart.com/used_cars/info.php?ID=1326109&DL=3801\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332147&DL=2014\
# https://www.sgcarmart.com/used_cars/info.php?ID=1299013&DL=3546
# https://www.sgcarmart.com/used_cars/info.php?ID=1334126&DL=3989\
# https://www.sgcarmart.com/used_cars/info.php?ID=1253863&DL=4731\
# https://www.sgcarmart.com/used_cars/info.php?ID=1272148&DL=3769\
# https://www.sgcarmart.com/used_cars/info.php?ID=1318545&DL=2870\
# https://www.sgcarmart.com/used_cars/info.php?ID=1270224&DL=3142\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331204&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330970&DL=1011\
# https://www.sgcarmart.com/used_cars/info.php?ID=1312515&DL=4667\
# https://www.sgcarmart.com/used_cars/info.php?ID=1290982&DL=4055\
# https://www.sgcarmart.com/used_cars/info.php?ID=1303298&DL=1266\
# https://www.sgcarmart.com/used_cars/info.php?ID=1324291&DL=3750\
# https://www.sgcarmart.com/used_cars/info.php?ID=1239976&DL=2469\
# https://www.sgcarmart.com/used_cars/info.php?ID=1322842&DL=3074\
# https://www.sgcarmart.com/used_cars/info.php?ID=1313671&DL=1028\
# https://www.sgcarmart.com/used_cars/info.php?ID=1289684&DL=4277\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333554&DL=3043\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334877&DL=3486\
# https://www.sgcarmart.com/used_cars/info.php?ID=1314415&DL=3579\
# https://www.sgcarmart.com/used_cars/info.php?ID=1298054&DL=2649\
# https://www.sgcarmart.com/used_cars/info.php?ID=1316190&DL=3875\
# https://www.sgcarmart.com/used_cars/info.php?ID=1305951&DL=4442\
# https://www.sgcarmart.com/used_cars/info.php?ID=1250213&DL=4277\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333974&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1324312&DL=2389\
# https://www.sgcarmart.com/used_cars/info.php?ID=1298738&DL=1026\
# https://www.sgcarmart.com/used_cars/info.php?ID=1294128&DL=3466\
# https://www.sgcarmart.com/used_cars/info.php?ID=1325181&DL=1245\
# https://www.sgcarmart.com/used_cars/info.php?ID=1311587&DL=3570\
# https://www.sgcarmart.com/used_cars/info.php?ID=1272476&DL=1353\
# https://www.sgcarmart.com/used_cars/info.php?ID=1327135&DL=1026\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331414&DL=2003\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332557&DL=1213\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331469&DL=4412\
# https://www.sgcarmart.com/used_cars/info.php?ID=1327058&DL=3269\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334672&DL=4561\
# https://www.sgcarmart.com/used_cars/info.php?ID=1303750&DL=2707\
# https://www.sgcarmart.com/used_cars/info.php?ID=1301915&DL=2804\
# https://www.sgcarmart.com/used_cars/info.php?ID=1329184&DL=1163\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334135&DL=2549\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333391&DL=2029\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332818&DL=4721\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334650&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333589&DL=2140\
# https://www.sgcarmart.com/used_cars/info.php?ID=1325883&DL=2023\
# https://www.sgcarmart.com/used_cars/info.php?ID=1277041&DL=3730\
# https://www.sgcarmart.com/used_cars/info.php?ID=1328325&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1318133&DL=2239\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331127&DL=2725\
# https://www.sgcarmart.com/used_cars/info.php?ID=1313675&DL=8008\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332655&DL=3573\
# https://www.sgcarmart.com/used_cars/info.php?ID=1317614&DL=1368\
# https://www.sgcarmart.com/used_cars/info.php?ID=1328280&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1302204&DL=2296\
# https://www.sgcarmart.com/used_cars/info.php?ID=1318665&DL=1238\
# https://www.sgcarmart.com/used_cars/info.php?ID=1240010&DL=1339\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331213&DL=2171\
# https://www.sgcarmart.com/used_cars/info.php?ID=1082122&DL=3382\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332118&DL=1400\
# https://www.sgcarmart.com/used_cars/info.php?ID=1271315&DL=4402\
# https://www.sgcarmart.com/used_cars/info.php?ID=1314820&DL=3122\
# https://www.sgcarmart.com/used_cars/info.php?ID=1308786&DL=2757\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331199&DL=4551\
# https://www.sgcarmart.com/used_cars/info.php?ID=1298797&DL=3426\
# https://www.sgcarmart.com/used_cars/info.php?ID=1281010&DL=4622\
# https://www.sgcarmart.com/used_cars/info.php?ID=1301941&DL=1213\
# https://www.sgcarmart.com/used_cars/info.php?ID=1316240&DL=3318\
# https://www.sgcarmart.com/used_cars/info.php?ID=1310035&DL=4691\
# https://www.sgcarmart.com/used_cars/info.php?ID=1293318&DL=1135\
# https://www.sgcarmart.com/used_cars/info.php?ID=1303282&DL=2049\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334872&DL=1277\
# https://www.sgcarmart.com/used_cars/info.php?ID=1302349&DL=4102\
# https://www.sgcarmart.com/used_cars/info.php?ID=1303412&DL=1238\
# https://www.sgcarmart.com/used_cars/info.php?ID=1315147&DL=4391\
# https://www.sgcarmart.com/used_cars/info.php?ID=1304046&DL=1189\
# https://www.sgcarmart.com/used_cars/info.php?ID=1329532&DL=1193\
# https://www.sgcarmart.com/used_cars/info.php?ID=1311374&DL=3271\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334904&DL=4391\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333551&DL=4579\
# https://www.sgcarmart.com/used_cars/info.php?ID=1295787&DL=3175\
# https://www.sgcarmart.com/used_cars/info.php?ID=1329150&DL=2341\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331598&DL=3758\
# https://www.sgcarmart.com/used_cars/info.php?ID=1325904&DL=3269\
# https://www.sgcarmart.com/used_cars/info.php?ID=1256316&DL=8008\
# https://www.sgcarmart.com/used_cars/info.php?ID=1329149&DL=1350\
# https://www.sgcarmart.com/used_cars/info.php?ID=1317170&DL=1024\
# https://www.sgcarmart.com/used_cars/info.php?ID=1263101&DL=3210\
# https://www.sgcarmart.com/used_cars/info.php?ID=1256102&DL=2456\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334235&DL=1032\
# https://www.sgcarmart.com/used_cars/info.php?ID=1271390&DL=4454\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334013&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332011&DL=1335\
# https://www.sgcarmart.com/used_cars/info.php?ID=1328219&DL=2793\
# https://www.sgcarmart.com/used_cars/info.php?ID=1299694&DL=4670\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331330&DL=3840\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330979&DL=3750\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330768&DL=4412\
# https://www.sgcarmart.com/used_cars/info.php?ID=1321633&DL=2689\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330913&DL=4419\
# https://www.sgcarmart.com/used_cars/info.php?ID=1326840&DL=3757\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332576&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1269619&DL=2049\
# https://www.sgcarmart.com/used_cars/info.php?ID=1081378&DL=1034\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334727&DL=8008\
# https://www.sgcarmart.com/used_cars/info.php?ID=1303350&DL=3647\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332689&DL=1020\
# https://www.sgcarmart.com/used_cars/info.php?ID=1292906&DL=1015\
# https://www.sgcarmart.com/used_cars/info.php?ID=1314878&DL=2456\
# https://www.sgcarmart.com/used_cars/info.php?ID=1310850&DL=3597\
# https://www.sgcarmart.com/used_cars/info.php?ID=1284869&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1322466&DL=2493\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332893&DL=3214\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330860&DL=3597\
# https://www.sgcarmart.com/used_cars/info.php?ID=1311709&DL=2189\
# https://www.sgcarmart.com/used_cars/info.php?ID=1182951&DL=2493\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334715&DL=2726\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334723&DL=3545\
# https://www.sgcarmart.com/used_cars/info.php?ID=1317404&DL=2303\
# https://www.sgcarmart.com/used_cars/info.php?ID=1138702&DL=3722\
# https://www.sgcarmart.com/used_cars/info.php?ID=1208895&DL=1034\
# https://www.sgcarmart.com/used_cars/info.php?ID=1296969&DL=3791\
# https://www.sgcarmart.com/used_cars/info.php?ID=1325766&DL=1026\
# https://www.sgcarmart.com/used_cars/info.php?ID=1316893&DL=3700\
# https://www.sgcarmart.com/used_cars/info.php?ID=1323851&DL=4500\
# https://www.sgcarmart.com/used_cars/info.php?ID=1294441&DL=8008\
# https://www.sgcarmart.com/used_cars/info.php?ID=1328269&DL=2341\
# https://www.sgcarmart.com/used_cars/info.php?ID=1324342&DL=3865\
# https://www.sgcarmart.com/used_cars/info.php?ID=1303424&DL=2296\
# https://www.sgcarmart.com/used_cars/info.php?ID=1317572&DL=1001\
# https://www.sgcarmart.com/used_cars/info.php?ID=1314749&DL=4555\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334481&DL=2192\
# https://www.sgcarmart.com/used_cars/info.php?ID=1311636&DL=1070\
# https://www.sgcarmart.com/used_cars/info.php?ID=1321219&DL=3318\
# https://www.sgcarmart.com/used_cars/info.php?ID=1326911&DL=4667\
# https://www.sgcarmart.com/used_cars/info.php?ID=1318917&DL=4073\
# https://www.sgcarmart.com/used_cars/info.php?ID=1326716&DL=3175\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330590&DL=4662\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331174&DL=2339\
# https://www.sgcarmart.com/used_cars/info.php?ID=1305053&DL=1266\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332883&DL=3597\
# https://www.sgcarmart.com/used_cars/info.php?ID=1279531&DL=2397\
# https://www.sgcarmart.com/used_cars/info.php?ID=1314056&DL=3845\
# https://www.sgcarmart.com/used_cars/info.php?ID=1327159&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332412&DL=3476\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331767&DL=3570\
# https://www.sgcarmart.com/used_cars/info.php?ID=1300431&DL=1429\
# https://www.sgcarmart.com/used_cars/info.php?ID=1289425&DL=1368\
# https://www.sgcarmart.com/used_cars/info.php?ID=1319004&DL=2291\
# https://www.sgcarmart.com/used_cars/info.php?ID=1267672&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1322659&DL=2984\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330847&DL=3597\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330845&DL=3597\
# https://www.sgcarmart.com/used_cars/info.php?ID=1311809&DL=3137\
# https://www.sgcarmart.com/used_cars/info.php?ID=1308756&DL=1213\
# https://www.sgcarmart.com/used_cars/info.php?ID=1317381&DL=3210\
# https://www.sgcarmart.com/used_cars/info.php?ID=1308865&DL=4442\
# https://www.sgcarmart.com/used_cars/info.php?ID=1307698&DL=2080\

# %%
print(len(listing_urls))
print(len(set(listing_urls)))
print(len(list(set(listing_urls))))
# Out:
# 2001
# 2001
# 2001

# %%
print(listing_urls[:10])
# Out:
# ['https://www.sgcarmart.com/used_cars/info.php?ID=1316564&DL=2689\\', 'https://www.sgcarmart.com/used_cars/info.php?ID=1286467&DL=1242\\', 'https://www.sgcarmart.com/used_cars/info.php?ID=1227438&DL=3811\\', 'https://www.sgcarmart.com/used_cars/info.php?ID=1333066&DL=1277\\', 'https://www.sgcarmart.com/used_cars/info.php?ID=1333470&DL=3590\\', 'https://www.sgcarmart.com/used_cars/info.php?ID=1247890&DL=3837\\', 'https://www.sgcarmart.com/used_cars/info.php?ID=1311531&DL=3318\\', 'https://www.sgcarmart.com/used_cars/info.php?ID=1315089&DL=3875\\', 'https://www.sgcarmart.com/used_cars/info.php?ID=1276589&DL=2976\\', 'https://www.sgcarmart.com/used_cars/info.php?ID=1334765&DL=1000\\']

# %% [markdown]
# ## 6. Create DataFrame

# %%
def scrape_car_data(listing_urls, filename='sgcarmart_used_cars_prices'):
    """
    Scrapes car data from the provided list of listing URLs and saves the data to a CSV file.

    Parameters:
    listing_urls (list): A list of URLs for the individual car listings.
    filename (str, optional): The name of the output CSV file (without the .csv extension). Defaults to 'sgcarmart_used_cars_prices'.
    """
    # Creating an empty DataFrame for attributes of interest
    df = pd.DataFrame(columns=[
        'LISTING_URL', 'BRAND', 'PRICE', 'DEPRE_YEARLY', 'REG_DATE', 'MILEAGE_KM',
        'MANUFACTURED_YEAR', 'ROAD_TAX_YEARLY', 'TRANSMISSION', 'DEREG_VALUE_FROM_SCRAPE_DATE',
        'SCRAPE_DATE', 'OMV', 'ARF', 'COE_FROM_SCRAPE_DATE', 'DAYS_OF_COE_LEFT',
        'ENGINE_CAPACITY_CC', 'CURB_WEIGHT_KG', 'NO_OF_OWNERS', 'VEHICLE_TYPE'
    ])

    i = 0 # Indexing rows in the DF
    for i, listingurl in enumerate(listing_urls):
        response = requests.get(listingurl)
        listing_url = BeautifulSoup(response.text, 'lxml')

        df.loc[i, 'LISTING_URL'] = listingurl
        df.loc[i, 'BRAND'] = brand_retrieval(listing_url)
        df.loc[i, 'PRICE'] = price_retrieval(listing_url)
        df.loc[i, 'DEPRE_YEARLY'] = depreciation_yearly_retrieval(listing_url)
        df.loc[i, 'REG_DATE'] = reg_date_retrieval(listing_url)
        df.loc[i, 'MILEAGE_KM'] = mileage_retrieval(listing_url)
        df.loc[i, 'MANUFACTURED_YEAR'] = manufactured_year_retrieval(listing_url)
        df.loc[i, 'ROAD_TAX_YEARLY'] = road_tax_retrieval(listing_url)
        df.loc[i, 'TRANSMISSION'] = transmission_retrieval(listing_url)
        df.loc[i, 'DEREG_VALUE_FROM_SCRAPE_DATE'] = dereg_value_retrieval(listing_url)
        df.loc[i, 'SCRAPE_DATE'] = datetime.now().strftime("%d/%m/%Y")
        df.loc[i, 'OMV'] = omv_retrieval(listing_url)
        df.loc[i, 'ARF'] = arf_retrieval(listing_url)
        df.loc[i, 'COE_FROM_SCRAPE_DATE'] = coe_retrieval(listing_url)
        df.loc[i, 'DAYS_OF_COE_LEFT'] = days_of_coe_retrieval(listing_url)
        df.loc[i, 'ENGINE_CAPACITY_CC'] = engine_capacity_retrieval(listing_url)
        df.loc[i, 'CURB_WEIGHT_KG'] = curb_weight_retrieval(listing_url)
        df.loc[i, 'NO_OF_OWNERS'] = number_of_owners_retrieval(listing_url)
        df.loc[i, 'VEHICLE_TYPE'] = type_of_vehicle_retrieval(listing_url)
        
        time.sleep(5)  # Prevent getting blocked by the website

    df.to_csv(f"{filename}.csv", index=True)

# %%
scrape_car_data(listing_urls)
df = pd.read_csv('sgcarmart_used_cars_prices.csv',index_col=0)
df
