# %% [markdown]
# # Web Scraping Used Cars on sgcarmart.com
# ## 1. Introduction
#
# ### This document outlines the process of web scraping data from sgcarmart.com, the largest online car marketplace in Singapore, to analyze the used car market.
#
# ### Respecting sgcarmart.com's Rules
# The scraping script will adhere to the guidelines outlined in sgcarmart.com's robots.txt file. Here's a summary of the restrictions:
#
# Crawlers must wait at least 5 seconds between requests (Crawl-delay: 5).
# Specific directories are off-limits for scraping, including:
# cgi-bin/
# images/
# mail/
# dealer/
# directory/premium/
# includes/
# phpads/
# update/
# upload/
#
# ### Data Extraction
# The script will focus on extracting the following information for each used car listing:
#
# Car Listing URL 'LISTING_URL',
# Car Brand and Model 'BRAND',
# Price 'PRICE',
# Depreciation Value Yearly 'DEPRE_YEARLY',
# Registered Date 'REG_DATE',
# Mileage in KM 'MILEAGE_KM',
# Year of Manufacture 'MANUFACTURED_YEAR',
# Road Tax Yearly 'ROAD_TAX_YEARLY',
# Automatic or Manual Tranmission 'TRANSMISSION',
# Deregistration Value as of Web Scraping DTD 'DEREG_VALUE_FROM_SCRAPE_DATE',
# Web Scraping DTD 'SCRAPE_DATE',
# Open Market Value (OMV) 'OMV',
# Additional Registration Fee (ARF) 'ARF',
# Certificate of Entitlement (COE) from Web Scraping DTD 'COE_FROM_SCRAPE_DATE',
# Number of Days till COE Expires 'DAYS_OF_COE_LEFT',
# Engine Capacity in CC 'ENGINE_CAPACITY_CC',
# Car Curb Weight in KG 'CURB_WEIGHT_KG',
# Number of Past Owners 'NO_OF_OWNERS',
# Vehicle Type 'VEHICLE_TYPE'
#
# This data will be used for further analysis of the used car market in Singapore.

# %% [markdown]
# ## 2. Import Libraries

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
import time
import re
from datetime import datetime

# %% [markdown]
# ## 3. Pre-defined Functions

# %%
# A set of functions is defined to extract specific attributes from a parsed individual car listing URL, with each function returning the corresponding attribute.

#Brand Retriever Function
def brand_retrieval(parsed_listing_url):
    """
    Retrieves the model name from the parsed car listing URL.

    Parameters:
    parsed_listing_url (BeautifulSoup object): The parsed HTML content of the car listing page.

    Returns:
    str or np.nan: The model name. Returns np.nan if the model name is not found.
    """
    try:
        # Find all script tags
        script_tags = parsed_listing_url.find_all('script')
        
        for script_tag in script_tags:
            script_text = script_tag.string
            if script_text:
                # Search for the model and vehicleConfiguration keywords
                model_match = re.search(r'"model"\s*:\s*"([^"]+)"', script_text)
                vehicle_config_match = re.search(r'"vehicleConfiguration"\s*:\s*"([^"]+)"', script_text)
                
                if model_match and vehicle_config_match:
                    model_name = model_match.group(1)
                    vehicle_config = vehicle_config_match.group(1)
                    
                    # Ensure the model name is between "model" and "vehicleConfiguration"
                    if model_name and vehicle_config:
                        return model_name
        return np.nan
    except (AttributeError, TypeError):
        return np.nan

# Price Retriever Function
def price_retrieval(parsed_listing_url):
    """
    Retrieves the price from the parsed car listing URL.

    Parameters:
    parsed_listing_url (BeautifulSoup): The parsed HTML of the car listing page.

    Returns:
    int or np.nan: The price of the car. Returns np.nan if the price information is not available or cannot be parsed.
    """
    price_elements = parsed_listing_url.find_all(class_="font_red")
    if price_elements:
        price_text = price_elements[0].text.strip()
        price_parts = price_text.split('$')
        if len(price_parts) < 2:
            return np.nan
        try:
            return int(price_parts[1].replace(',', ''))
        except ValueError:
            return np.nan
    else:
        return np.nan

# Deprecration Value Per Year Retriever Function
def depreciation_yearly_retrieval(parsed_listing_url):
    """
    Retrieves the yearly depreciation value from the parsed car listing URL.

    Parameters:
    parsed_listing_url (BeautifulSoup): The parsed HTML of the car listing page.

    Returns:
    int or np.nan: The yearly depreciation value. Returns np.nan if the depreciation information is not available or cannot be parsed.
    """
    # Find all rows with the class 'row_bg'
#    row_bg_elements = parsed_listing_url.find_all('tr', class_="row_bg")
#    for row in row_bg_elements:
#        # Find the 'Depreciation' label within the row
#        depreciation_label = row.find('td', string='Depreciation')
#        if depreciation_label:
#            # Find the next sibling element which contains the depreciation value
#            depreciation_value = depreciation_label.find_next_sibling('td', valign="top")
#            if depreciation_value:
#                depreciation_value_text = depreciation_value.text.strip()
#                depreciation_parts = depreciation_value_text.split('$')
#                if len(depreciation_parts) < 2:
#                    return np.nan
#                try:
#                    return int(depreciation_parts[1].replace(',', '').split('/')[0])
#                except ValueError:
#                    return np.nan
#    return np.nan

    # Find the <strong>Depreciation</strong> element
    depreciation_label = parsed_listing_url.find('strong', string='Depreciation')
    if depreciation_label:
        # Find the parent <td> element
        depreciation_td = depreciation_label.find_parent('td')
        if depreciation_td:
            # Find the next sibling <td> element with valign='top'
            depreciation_value = depreciation_td.find_next_sibling('td', valign='top')
            if depreciation_value:
                depreciation_value_text = depreciation_value.text.strip()
                depreciation_parts = depreciation_value_text.split('$')
                if len(depreciation_parts) < 2:
                    return np.nan
                try:
                    return int(depreciation_parts[1].replace(',', '').split('/')[0])
                except ValueError:
                    return np.nan
            else:
                return np.nan
        else:
            return np.nan
    else:
        return np.nan

# Road Tax Per Year Retriever
def road_tax_retrieval(parsed_listing_url):
    """
    Retrieves the yearly road tax from the parsed car listing URL.

    Parameters:
    parsed_listing_url (BeautifulSoup): The parsed HTML of the car listing page.

    Returns:
    int or np.nan: The yearly road tax. Returns np.nan if the road tax information is not available or cannot be parsed.
    """
    each_info_elements = parsed_listing_url.find_all(class_='eachInfo')
    for element in each_info_elements:
        row_title = element.find(class_='row_title')
        if row_title and 'Road Tax' in row_title.text:
            row_info = element.find(class_='row_info')
            if row_info:
                road_tax_text = row_info.text.strip()
                if '/yr' in road_tax_text:
                    try:
                        return int(road_tax_text.split('/yr')[0].replace('$', '').replace(',', '').strip())
                    except ValueError:
                        return np.nan
    return np.nan

# Registered Date Retriever
def reg_date_retrieval(parsed_listing_url):
    """
    Retrieves the registration date from the parsed car listing URL.

    Parameters:
    parsed_listing_url (BeautifulSoup): The parsed HTML of the car listing page.

    Returns:
    str or np.nan: The registration date of the car. Returns np.nan if the registration date information is not available or cannot be parsed.
    """
    row_bg_elements = parsed_listing_url.find_all(class_='row_bg')
    if len(row_bg_elements) > 1:
        td_elements = row_bg_elements[1].find_all('td')
        if len(td_elements) > 3:
            reg_date = td_elements[3].text.split()[0].split('(')[0]
            return reg_date
    return np.nan

# Days of COE Retriever
def days_of_coe_retrieval(parsed_listing_url):
    """
    Retrieves the days of COE left from the parsed car listing URL.

    Parameters:
    parsed_listing_url (BeautifulSoup object): The parsed HTML content of the car listing page.

    Returns:
    str or np.nan: The days of COE left. Returns np.nan if the information is not found.
    """
    try:
        row_bg_elements = parsed_listing_url.find_all(class_='row_bg')
        if len(row_bg_elements) > 1:
            td_elements = row_bg_elements[1].find_all('td')
            if len(td_elements) > 3:
                days_of_coe_left_text = td_elements[3].text.split('(')[1].split('COE')[0].strip()
                return yr_mm_dd_cleaner(days_of_coe_left_text)
        return np.nan
    except (IndexError, AttributeError, ValueError):
        return np.nan

def yr_mm_dd_cleaner(str1):
    """
    Accepts a string that may or may include the elements yr, mths, and days,
    and converts the whole string into the number of days.

    Parameters:
    str1 (str): A string representing the duration in the format "Xyr Xmth Xdays".

    Returns:
    int: The number of days.
    """
    days = 0
    for unit in ['yr', 'mth', 'day']:
        value = int(next((int(char) for char in str1 if char.isdigit() and unit in str1), 0))
        days += value * {'yr': 365, 'mth': 30, 'day': 1}[unit]
    return days

# Mileage Retriever
def mileage_retrieval(parsed_listing_url):
    """
    Retrieves the mileage in kilometers from the parsed listing URL.

    Parameters:
    parsed_listing_url (BeautifulSoup): The parsed HTML of the car listing page.

    Returns:
    int or np.nan: The mileage in kilometers. Returns np.nan if the mileage information is not available.
    """
    each_info_elements = parsed_listing_url.find_all(class_='eachInfo')
    for element in each_info_elements:
        row_title = element.find(class_='row_title')
        if row_title and 'Mileage' in row_title.text:
            row_info = element.find(class_='row_info')
            if row_info:
                mileage_text = row_info.text.strip()
                mileage_parts = mileage_text.split('km')
                if len(mileage_parts) < 2:
                    return np.nan
                try:
                    return int(mileage_parts[0].replace(',', '').strip())
                except ValueError:
                    return np.nan
    return np.nan

# Manufactured Year Retriever
def manufactured_year_retrieval(parsed_listing_url):
    """
    Retrieves the manufactured year from the parsed car listing URL.

    Parameters:
    parsed_listing_url (BeautifulSoup): The parsed HTML of the car listing page.

    Returns:
    str or np.nan: The manufactured year of the car. Returns np.nan if the manufactured year information is not available or cannot be parsed.
    """
    row_info_elements = parsed_listing_url.find_all(class_='row_info')
    if len(row_info_elements) > 6:
        manufactured_year = row_info_elements[6].text.strip()
        return manufactured_year.split()[0]
    return np.nan

# Transmission Retriever
def transmission_retrieval(parsed_listing_url):
    """
    Retrieves the transmission type from the parsed car listing URL.

    Parameters:
    parsed_listing_url (BeautifulSoup): The parsed HTML of the car listing page.

    Returns:
    str or np.nan: The transmission type of the car. Returns np.nan if the transmission information is not available or cannot be parsed.
    """
    row_info_elements = parsed_listing_url.find_all(class_='row_info')
    if len(row_info_elements) > 7:
        transmission = row_info_elements[7].text.strip()
        return transmission.split()[0]
    return np.nan

# Deregistration Value Retriever
def dereg_value_retrieval(parsed_listing_url):
    """
    Retrieves the deregistration value from the parsed car listing URL.

    Args:
        parsed_listing_url (BeautifulSoup): The parsed HTML of the car listing.

    Returns:
        int or np.nan: The deregistration value. Returns np.nan if the deregistration value information is not available or cannot be parsed.
    """
    each_info_elements = parsed_listing_url.find_all(class_='eachInfo')
    for element in each_info_elements:
        row_title = element.find(class_='row_title')
        if row_title and 'Dereg Value' in row_title.text:
            row_info = element.find(class_='row_info')
            if row_info:
                dereg_value_text = row_info.text.strip()
                dereg_value_parts = dereg_value_text.split('$')
                if len(dereg_value_parts) < 2:
                    return np.nan
                try:
                    return int(dereg_value_parts[1].replace(',', '').split()[0])
                except ValueError:
                    return np.nan
    return np.nan

# Open Market Value Retriever
def omv_retrieval(parsed_listing_url):
    """
    Retrieves the Open Market Value (OMV) from the parsed car listing URL.

    Args:
        parsed_listing_url (BeautifulSoup): The parsed HTML of the car listing.

    Returns:
        int or np.nan: The Open Market Value (OMV). Returns np.nan if the OMV information is not available or cannot be parsed.
    """
    row_info_elements = parsed_listing_url.find_all(class_='row_info')
    if len(row_info_elements) > 8:
        omv_text = row_info_elements[8].text.strip()
        omv_parts = omv_text.split('$')
        if len(omv_parts) < 2:
            return np.nan
        try:
            return int(omv_parts[1].replace(',', ''))
        except ValueError:
            return np.nan
    else:
        return np.nan
    
# ARF Retriever
def arf_retrieval(parsed_listing_url):
    """
    Retrieves the Additional Registration Fee (ARF) from the parsed car listing URL.

    Args:
        parsed_listing_url (BeautifulSoup): The parsed HTML of the car listing.

    Returns:
        int or np.nan: The Additional Registration Fee (ARF). Returns np.nan if the ARF information is not available or cannot be parsed.
    """
    row_info_elements = parsed_listing_url.find_all(class_='row_info')
    if len(row_info_elements) > 9:
        arf_text = row_info_elements[9].text.strip()
        arf_parts = arf_text.split('$')
        if len(arf_parts) < 2:
            return np.nan
        try:
            return int(arf_parts[1].replace(',', ''))
        except ValueError:
            return np.nan
    else:
        return np.nan

# COE Price retriever 
def coe_retrieval(parsed_listing_url):
    """
    Retrieves the Certificate of Entitlement (COE) price from the parsed car listing URL.

    Args:
        parsed_listing_url (BeautifulSoup): The parsed HTML of the car listing.

    Returns:
        int or np.nan: The Certificate of Entitlement (COE) price. Returns np.nan if the COE price information is not available or cannot be parsed.
    """
    row_info_elements = parsed_listing_url.find_all(class_='row_info')
    if len(row_info_elements) > 3:
        coe_text = row_info_elements[3].text.strip()
        coe_parts = coe_text.split('$')
        if len(coe_parts) < 2:
            return np.nan
        try:
            return int(coe_parts[1].replace(',', ''))
        except ValueError:
            return np.nan
    else:
        return np.nan

# Engine Capacity Retriever
def engine_capacity_retrieval(parsed_listing_url):
    """
    Retrieves the engine capacity in cubic centimeters (CC) from the parsed car listing URL.

    Args:
        parsed_listing_url (BeautifulSoup): The parsed HTML of the car listing.

    Returns:
        int or np.nan: The engine capacity in cubic centimeters (CC). Returns np.nan if the engine capacity information is not available or cannot be parsed.
    """
    row_info_elements = parsed_listing_url.find_all(class_='row_info')
    if len(row_info_elements) > 4:
        engine_capacity_text = row_info_elements[4].text.strip()
        engine_capacity_parts = engine_capacity_text.split('cc')
        if len(engine_capacity_parts) < 2:
            return np.nan
        try:
            return int(engine_capacity_parts[0].replace(',', '').strip())
        except ValueError:
            return np.nan
    else:
        return np.nan

# Curb Weight Retriever
def curb_weight_retrieval(parsed_listing_url):
    """
    Retrieves the curb weight in kilograms (KG) from the parsed car listing URL.

    Args:
        parsed_listing_url (BeautifulSoup): The parsed HTML of the car listing.

    Returns:
        int or np.nan: The curb weight in kilograms (KG). Returns np.nan if the curb weight information is not available or cannot be parsed.
    """
    row_info_elements = parsed_listing_url.find_all(class_='row_info')
    if len(row_info_elements) > 5:
        curb_weight_text = row_info_elements[5].text.strip()
        curb_weight_parts = curb_weight_text.split()
        if len(curb_weight_parts) < 2:
            return np.nan
        try:
            return int(curb_weight_parts[0].replace(',', '').strip())
        except ValueError:
            return np.nan
    else:
        return np.nan

def number_of_owners_retrieval(parsed_listing_url):
    """
    Retrieves the number of owners from the parsed car listing URL.

    Parameters:
    parsed_listing_url (BeautifulSoup object): The parsed HTML content of the car listing page.

    Returns:
    int or np.nan: The number of owners. Returns np.nan if the number of owners is not found.
    """
    try:
        # Find the div containing the "No. of Owners" label
        owner_info_div = parsed_listing_url.find(string="No. of Owners")
        if owner_info_div:
            # The number of owners is in the next sibling div with class 'row_info'
            no_of_owners_text = owner_info_div.find_next("div", class_="row_info").text.strip()
            no_of_owners = int(no_of_owners_text)
        else:
            no_of_owners = np.nan
    except (AttributeError, ValueError, TypeError):
        no_of_owners = np.nan
    return no_of_owners

# Type of Vehicle Retriever
def type_of_vehicle_retrieval(parsed_listing_url):
    """
    Retrieves the type of vehicle from the parsed car listing URL.

    Parameters:
    parsed_listing_url (BeautifulSoup object): The parsed HTML content of the car listing page.

    Returns:
    str or np.nan: The type of vehicle. Returns np.nan if the type of vehicle information is not available or cannot be parsed.
    """
    try:
        type_of_vehicle = parsed_listing_url.find(class_='row_bg1').find_all('td')[1].text.strip()
        return type_of_vehicle
    except (IndexError, AttributeError):
        return np.nan
    
def type_of_fuel_retrieval(parsed_listing_url):
    """
    Retrieves the fuel type from the parsed car listing URL.

    Parameters:
    parsed_listing_url (BeautifulSoup object): The parsed HTML content of the car listing page.

    Returns:
    str or np.nan: The fuel type. Returns np.nan if the fuel type information is not available or cannot be parsed.
    """
    try:
        # Find the script tag containing the JSON-like data
        script_tags = parsed_listing_url.find_all("script")
        for script_tag in script_tags:
            script_text = str(script_tag.string)
            if script_text and '"fuelType": "' in script_text:
                # Find the "fuelType" field
                fuel_type_start = script_text.find('"fuelType": "') + len('"fuelType": "')
                fuel_type_end = script_text.find('"', fuel_type_start)
                fuel_type = script_text[fuel_type_start:fuel_type_end]
                return fuel_type
        return np.nan
    except (AttributeError, IndexError, TypeError):
        return np.nan

# %% [markdown]
# ## 4. Get Links For All Postings
#
# Links for all the car postings will be stored in a list before accessing them one by one for data extraction

# %%
# Create listings URLs to iterate through
main_page_listing_list = [] # create list to store search pages
for idx, link in enumerate(range(500)):
    url = "https://www.sgcarmart.com/used-cars/listing?avl=a&limit=100&vts[]=2&page=" + str(idx+1) #search by of car listings per page
    main_page_listing_list.append(url)

# %%
print(main_page_listing_list,'\n','\n', len(main_page_listing_list))
# Out:
# ['https://www.sgcarmart.com/used-cars/listing?avl=a&limit=100&vts[]=2&page=1', 'https://www.sgcarmart.com/used-cars/listing?avl=a&limit=100&vts[]=2&page=2', 'https://www.sgcarmart.com/used-cars/listing?avl=a&limit=100&vts[]=2&page=3', 'https://www.sgcarmart.com/used-cars/listing?avl=a&limit=100&vts[]=2&page=4', 'https://www.sgcarmart.com/used-cars/listing?avl=a&limit=100&vts[]=2&page=5', 'https://www.sgcarmart.com/used-cars/listing?avl=a&limit=100&vts[]=2&page=6', 'https://www.sgcarmart.com/used-cars/listing?avl=a&limit=100&vts[]=2&page=7', 'https://www.sgcarmart.com/used-cars/listing?avl=a&limit=100&vts[]=2&page=8', 'https://www.sgcarmart.com/used-cars/listing?avl=a&limit=100&vts[]=2&page=9', 'https://www.sgcarmart.com/used-cars/listing?avl=a&limit=100&vts[]=2&page=10', 'https://www.sgcarmart.com/used-cars/listing?avl=a&limit=100&vts[]=2&page=11', 'https://www.sgcarmart.com/used-cars/listing?avl=a&limit=100&vts[]=2&page=12', 'https://www.sgcarmart.com/used-cars/listing?avl=a&limit=100&vts[]=2&page=13', 'https://www.sgcarmart.com/used-cars/listing?avl=a&limit=100&vts[]=2&page=14', 'https://www.sgcarmart.com/used-cars/listing?avl=a&limit=100&vts[]=2&page=15', 'https://www.sgcarmart.com/used-cars/listing?avl=a&limit=100&vts[]=2&page=16', 'https://www.sgcarmart.com/used-cars/listing?avl=a&limit=100&vts[]=2&page=17', 'https://www.sgcarmart.com/used-cars/listing?avl=a&limit=100&vts[]=2&page=18', 'https://www.sgcarmart.com/used-cars/listing?avl=a&limit=100&vts[]=2&page=19', 'https://www.sgcarmart.com/used-cars/listing?avl=a&limit=100&vts[]=2&page=20', 'https://www.sgcarmart.com/used-cars/listing?avl=a&limit=100&vts[]=2&page=21', 'https://www.sgcarmart.com/used-cars/listing?avl=a&limit=100&vts[]=2&page=22', 'https://www.sgcarmart.com/used-cars/listing?avl=a&limit=100&vts[]=2&page=23', 'https://www.sgcarmart.com/used-cars/listing?avl=a&limit=100&vts[]=2&page=24', 'https://www.sgcarmart.com/used-cars/listing?avl=a&limit=100&vts[]=2&page=25', 'https://www.sgcarmart.com/used-cars/listing?avl=a&limit=100&vts[]=2&page=26', 'https://www.sgcarmart.com/used-cars/listing?avl=a&limit=100&vts[]=2&page=27', 'https://www.sgcarmart.com/used-cars/listing?avl=a&limit=100&vts[]=2&page=28', 'https://www.sgcarmart.com/used-cars/listing?avl=a&limit=100&vts[]=2&page=29', 'https://www.sgcarmart.com/used-cars/listing?avl=a&limit=100&vts[]=2&page=30', 'https://www.sgcarmart.com/used-cars/listing?avl=a&limit=100&vts[]=2&page=31', 'https://www.sgcarmart.com/used-cars/listing?avl=a&limit=100&vts[]=2&page=32', 'https://www.sgcarmart.com/used-cars/listing?avl=a&limit=100&vts[]=2&page=33', 'https://www.sgcarmart.com/used-cars/listing?avl=a&limit=100&vts[]=2&page=34', 'https://www.sgcarmart.com/used-cars/listing?avl=a&limit=100&vts[]=2&page=35', 'https://www.sgcarmart.com/used-cars/listing?avl=a&limit=100&vts[]=2&page=36', 'https://www.sgcarmart.com/used-cars/listing?avl=a&limit=100&vts[]=2&page=37', 'https://www.sgcarmart.com/used-cars/listing?avl=a&limit=100&vts[]=2&page=38', 'https://www.sgcarmart.com/used-cars/listing?avl=a&limit=100&vts[]=2&page=39', 'https://www.sgcarmart.com/used-cars/listing?avl=a&limit=100&vts[]=2&page=40', 'https://www.sgcarmart.com/used-cars/listing?avl=a&limit=100&vts[]=2&page=41', 'https://www.sgcarmart.com/used-cars/listing?avl=a&limit=100&vts[]=2&page=42', 'https://www.sgcarmart.com/used-cars/listing?avl=a&limit=100&vts[]=2&page=43', 'https://www.sgcarmart.com/used-cars/listing?avl=a&limit=100&vts[]=2&page=44', 'https://www.sgcarmart.com/used-cars/listing?avl=a&limit=100&vts[]=2&page=45', 'https://www.sgcarmart.com/used-cars/listing?avl=a&limit=100&vts[]=2&page=46', 'https://www.sgcarmart.com/used-cars/listing?avl=a&limit=100&vts[]=2&page=47', 'https://www.sgcarmart.com/used-cars/listing?avl=a&limit=100&vts[]=2&page=48', 'https://www.sgcarmart.com/used-cars/listing?avl=a&limit=100&vts[]=2&page=49', 'https://www.sgcarmart.com/used-cars/listing?avl=a&limit=100&vts[]=2&page=50', 'https://www.sgcarmart.com/used-cars/listing?avl=a&limit=1 ...
#
#  500

# %% [markdown]
# ## 5. Retrieval of Individual Listing URLs from Search Pages

# %%
# Base url, or you can think of this as the individual car listing prefix
base_url = 'https://www.sgcarmart.com/used_cars/'
listing_urls = set()  # Use a set to avoid duplicates

# Acquiring indvidual car listings    
for main_link in main_page_listing_list:
   
    # Make a request to the website and get the object
    content = requests.get(main_link)

    # Parse the HTML text
    soup = BeautifulSoup(content.text, 'lxml')

    # Find every single URL in the webpage , refer to this post: # https://stackoverflow.com/questions/46490626/getting-all-links-from-a-page-beautiful-soup
    # This returns a list of every tag that contains a link in one main link (each element in main page listing)

    # Find all the script tags in the webpage
    script_tags = soup.find_all('script')

    # Extract the desired links from the script tags
    for script_tag in script_tags:
        script_text = str(script_tag.string)
        if script_text:
            # Find all occurrences of 'info.php?ID=' and 'DL=' in the script text
            start_indices = [i for i in range(len(script_text)) if script_text.startswith('info.php?ID=', i)]
            for start_index in start_indices:
                end_index = script_text.find('"', start_index)
                link = script_text[start_index:end_index]
                if 'DL=' in link:
                    # Remove unwanted part if present
                    if 'u0026GASRC=sgcm\\' in link:
                        link = link.replace('u0026GASRC=sgcm\\', '')
                    link = link.replace('\\u0026', '&').replace('%5C%5C', '')
                    listing_urls.add(base_url + link)  # Add to set to ensure uniqueness

    # Add a delay to prevent getting blocked
    time.sleep(5)
    
# Convert the set back to a list
listing_urls = list(listing_urls)

# Print the retrieved links
for link in listing_urls:
    print(link)
# Out:
# https://www.sgcarmart.com/used_cars/info.php?ID=1293490&DL=4524\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335107&DL=2876\
# https://www.sgcarmart.com/used_cars/info.php?ID=1319958&DL=1188\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335957&DL=4014\
# https://www.sgcarmart.com/used_cars/info.php?ID=1319609&DL=2875\
# https://www.sgcarmart.com/used_cars/info.php?ID=1317859&DL=4516\
# https://www.sgcarmart.com/used_cars/info.php?ID=1336144&DL=2547\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333407&DL=1136\
# https://www.sgcarmart.com/used_cars/info.php?ID=1238413&DL=2958\
# https://www.sgcarmart.com/used_cars/info.php?ID=1310552&DL=4731\
# https://www.sgcarmart.com/used_cars/info.php?ID=1336120&DL=4298\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332855&DL=4343\
# https://www.sgcarmart.com/used_cars/info.php?ID=1300697&DL=3392\
# https://www.sgcarmart.com/used_cars/info.php?ID=1312030&DL=4111\
# https://www.sgcarmart.com/used_cars/info.php?ID=1263451&DL=2339\
# https://www.sgcarmart.com/used_cars/info.php?ID=1303473&DL=3723\
# https://www.sgcarmart.com/used_cars/info.php?ID=1318293&DL=2984\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334057&DL=2549\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332636&DL=3414\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335831&DL=2341\
# https://www.sgcarmart.com/used_cars/info.php?ID=1319680&DL=3318\
# https://www.sgcarmart.com/used_cars/info.php?ID=1313360&DL=3160\
# https://www.sgcarmart.com/used_cars/info.php?ID=1321293&DL=3750\
# https://www.sgcarmart.com/used_cars/info.php?ID=1294313&DL=4241\
# https://www.sgcarmart.com/used_cars/info.php?ID=1287176&DL=2454\
# https://www.sgcarmart.com/used_cars/info.php?ID=1336219&DL=2425\
# https://www.sgcarmart.com/used_cars/info.php?ID=1311225&DL=4508\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332610&DL=4609\
# https://www.sgcarmart.com/used_cars/info.php?ID=1264097&DL=1188\
# https://www.sgcarmart.com/used_cars/info.php?ID=1320734&DL=2875\
# https://www.sgcarmart.com/used_cars/info.php?ID=1313476&DL=1061\
# https://www.sgcarmart.com/used_cars/info.php?ID=1317520&DL=3368\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332769&DL=4313\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330335&DL=3318\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333494&DL=3590\
# https://www.sgcarmart.com/used_cars/info.php?ID=1313673&DL=3175\
# https://www.sgcarmart.com/used_cars/info.php?ID=1314978&DL=2303\
# https://www.sgcarmart.com/used_cars/info.php?ID=1323291&DL=3570\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334291&DL=1344\
# https://www.sgcarmart.com/used_cars/info.php?ID=1313613&DL=8008\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335498&DL=3301\
# https://www.sgcarmart.com/used_cars/info.php?ID=1323449&DL=1090\
# https://www.sgcarmart.com/used_cars/info.php?ID=1306769&DL=4537\
# https://www.sgcarmart.com/used_cars/info.php?ID=1319803&DL=3709\
# https://www.sgcarmart.com/used_cars/info.php?ID=1307751&DL=4481\
# https://www.sgcarmart.com/used_cars/info.php?ID=1317834&DL=3750\
# https://www.sgcarmart.com/used_cars/info.php?ID=1291585&DL=1359\
# https://www.sgcarmart.com/used_cars/info.php?ID=1295672&DL=2332\
# https://www.sgcarmart.com/used_cars/info.php?ID=1239161&DL=1079\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332793&DL=3892\
# https://www.sgcarmart.com/used_cars/info.php?ID=1287847&DL=2080\
# https://www.sgcarmart.com/used_cars/info.php?ID=1285349&DL=3507\
# https://www.sgcarmart.com/used_cars/info.php?ID=1319964&DL=1188\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332469&DL=3210\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332925&DL=2793\
# https://www.sgcarmart.com/used_cars/info.php?ID=1299084&DL=3160\
# https://www.sgcarmart.com/used_cars/info.php?ID=1319371&DL=4523\
# https://www.sgcarmart.com/used_cars/info.php?ID=1290339&DL=2984\
# https://www.sgcarmart.com/used_cars/info.php?ID=1318279&DL=3730\
# https://www.sgcarmart.com/used_cars/info.php?ID=1308958&DL=3902\
# https://www.sgcarmart.com/used_cars/info.php?ID=1287349&DL=2875\
# https://www.sgcarmart.com/used_cars/info.php?ID=1336319&DL=3163\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335851&DL=2296\
# https://www.sgcarmart.com/used_cars/info.php?ID=1315767&DL=3321\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334281&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1326309&DL=2083\
# https://www.sgcarmart.com/used_cars/info.php?ID=1305946&DL=3008\
# https://www.sgcarmart.com/used_cars/info.php?ID=1315062&DL=3597\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334489&DL=3475\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334731&DL=4717\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332301&DL=3911\
# https://www.sgcarmart.com/used_cars/info.php?ID=1300626&DL=2757\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330021&DL=4412\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330344&DL=1015\
# https://www.sgcarmart.com/used_cars/info.php?ID=1308775&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1261647&DL=4078\
# https://www.sgcarmart.com/used_cars/info.php?ID=1247722&DL=8008\
# https://www.sgcarmart.com/used_cars/info.php?ID=1317588&DL=2408\
# https://www.sgcarmart.com/used_cars/info.php?ID=1326753&DL=2296\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332541&DL=4645\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331375&DL=2341\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334641&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333517&DL=4404\
# https://www.sgcarmart.com/used_cars/info.php?ID=1314982&DL=3911\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333246&DL=3137\
# https://www.sgcarmart.com/used_cars/info.php?ID=1326674&DL=4412\
# https://www.sgcarmart.com/used_cars/info.php?ID=1308192&DL=2741\
# https://www.sgcarmart.com/used_cars/info.php?ID=1311457&DL=3887\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335109&DL=1177\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335004&DL=3381\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335088&DL=3318\
# https://www.sgcarmart.com/used_cars/info.php?ID=1314554&DL=3034\
# https://www.sgcarmart.com/used_cars/info.php?ID=1222103&DL=4189\
# https://www.sgcarmart.com/used_cars/info.php?ID=1322684&DL=4558\
# https://www.sgcarmart.com/used_cars/info.php?ID=1305342&DL=2023\
# https://www.sgcarmart.com/used_cars/info.php?ID=1311165&DL=2875\
# https://www.sgcarmart.com/used_cars/info.php?ID=1309459&DL=1177\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334025&DL=3358\
# https://www.sgcarmart.com/used_cars/info.php?ID=1314871&DL=1240\
# https://www.sgcarmart.com/used_cars/info.php?ID=1258046&DL=2356\
# https://www.sgcarmart.com/used_cars/info.php?ID=1241768&DL=2356\
# https://www.sgcarmart.com/used_cars/info.php?ID=1296262&DL=2011\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332064&DL=1032\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335045&DL=4502\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335835&DL=1193\
# https://www.sgcarmart.com/used_cars/info.php?ID=1307921&DL=3106\
# https://www.sgcarmart.com/used_cars/info.php?ID=1315870&DL=3541\
# https://www.sgcarmart.com/used_cars/info.php?ID=1324321&DL=1164\
# https://www.sgcarmart.com/used_cars/info.php?ID=1322648&DL=2728\
# https://www.sgcarmart.com/used_cars/info.php?ID=1299004&DL=2741\
# https://www.sgcarmart.com/used_cars/info.php?ID=1295692&DL=3163\
# https://www.sgcarmart.com/used_cars/info.php?ID=1313363&DL=4529\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332309&DL=1155\
# https://www.sgcarmart.com/used_cars/info.php?ID=1288498&DL=3405\
# https://www.sgcarmart.com/used_cars/info.php?ID=1326914&DL=3648\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334456&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1327181&DL=2097\
# https://www.sgcarmart.com/used_cars/info.php?ID=1293286&DL=4649\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332426&DL=3318\
# https://www.sgcarmart.com/used_cars/info.php?ID=1328923&DL=4508\
# https://www.sgcarmart.com/used_cars/info.php?ID=1313707&DL=3845\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333335&DL=3079\
# https://www.sgcarmart.com/used_cars/info.php?ID=1216875&DL=4449\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330625&DL=3079\
# https://www.sgcarmart.com/used_cars/info.php?ID=1301915&DL=2804\
# https://www.sgcarmart.com/used_cars/info.php?ID=1267712&DL=3730\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335041&DL=3426\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333853&DL=3117\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335666&DL=1311\
# https://www.sgcarmart.com/used_cars/info.php?ID=1328900&DL=2446\
# https://www.sgcarmart.com/used_cars/info.php?ID=1301734&DL=8008\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334262&DL=3750\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331916&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334667&DL=4743\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333189&DL=2341\
# https://www.sgcarmart.com/used_cars/info.php?ID=1321763&DL=1020\
# https://www.sgcarmart.com/used_cars/info.php?ID=1328474&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1336098&DL=3038\
# https://www.sgcarmart.com/used_cars/info.php?ID=1294161&DL=4550\
# https://www.sgcarmart.com/used_cars/info.php?ID=1326078&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1287757&DL=4414\
# https://www.sgcarmart.com/used_cars/info.php?ID=1202127&DL=3573\
# https://www.sgcarmart.com/used_cars/info.php?ID=1312523&DL=3175\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331368&DL=2030\
# https://www.sgcarmart.com/used_cars/info.php?ID=1299013&DL=3546\
# https://www.sgcarmart.com/used_cars/info.php?ID=1324275&DL=3456\
# https://www.sgcarmart.com/used_cars/info.php?ID=1336321&DL=4647\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334338&DL=2163\
# https://www.sgcarmart.com/used_cars/info.php?ID=1263891&DL=2356\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332521&DL=3043\
# https://www.sgcarmart.com/used_cars/info.php?ID=1317404&DL=2303\
# https://www.sgcarmart.com/used_cars/info.php?ID=1325947&DL=8008\
# https://www.sgcarmart.com/used_cars/info.php?ID=1306755&DL=1340\
# https://www.sgcarmart.com/used_cars/info.php?ID=1296451&DL=3648\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332591&DL=4323\
# https://www.sgcarmart.com/used_cars/info.php?ID=1303831&DL=2080\
# https://www.sgcarmart.com/used_cars/info.php?ID=1315509&DL=2080\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332695&DL=4405\
# https://www.sgcarmart.com/used_cars/info.php?ID=1320926&DL=1015\
# https://www.sgcarmart.com/used_cars/info.php?ID=1328921&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1292685&DL=8008\
# https://www.sgcarmart.com/used_cars/info.php?ID=1304073&DL=3911\
# https://www.sgcarmart.com/used_cars/info.php?ID=1326542&DL=3778\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333164&DL=3973\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335295&DL=3426\
# https://www.sgcarmart.com/used_cars/info.php?ID=1291191&DL=1155\
# https://www.sgcarmart.com/used_cars/info.php?ID=1315830&DL=4147\
# https://www.sgcarmart.com/used_cars/info.php?ID=1320052&DL=4481\
# https://www.sgcarmart.com/used_cars/info.php?ID=1290254&DL=2244\
# https://www.sgcarmart.com/used_cars/info.php?ID=1254261&DL=2849\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333220&DL=3597\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334095&DL=2440\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334732&DL=2163\
# https://www.sgcarmart.com/used_cars/info.php?ID=1262833&DL=3004\
# https://www.sgcarmart.com/used_cars/info.php?ID=1313585&DL=3163\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332443&DL=3998\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330272&DL=2140\
# https://www.sgcarmart.com/used_cars/info.php?ID=1313433&DL=3159\
# https://www.sgcarmart.com/used_cars/info.php?ID=1327672&DL=3283\
# https://www.sgcarmart.com/used_cars/info.php?ID=1117448&DL=1177\
# https://www.sgcarmart.com/used_cars/info.php?ID=1321085&DL=3932\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334207&DL=3164\
# https://www.sgcarmart.com/used_cars/info.php?ID=1314597&DL=4559\
# https://www.sgcarmart.com/used_cars/info.php?ID=1336288&DL=3271\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335472&DL=2050\
# https://www.sgcarmart.com/used_cars/info.php?ID=1308656&DL=3757\
# https://www.sgcarmart.com/used_cars/info.php?ID=1322873&DL=3648\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333396&DL=2549\
# https://www.sgcarmart.com/used_cars/info.php?ID=1314868&DL=3597\
# https://www.sgcarmart.com/used_cars/info.php?ID=1321785&DL=3811\
# https://www.sgcarmart.com/used_cars/info.php?ID=1252376&DL=1094\
# https://www.sgcarmart.com/used_cars/info.php?ID=1301178&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1328215&DL=3518\
# https://www.sgcarmart.com/used_cars/info.php?ID=1328755&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1301234&DL=4617\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332675&DL=3851\
# https://www.sgcarmart.com/used_cars/info.php?ID=1328326&DL=2189\
# https://www.sgcarmart.com/used_cars/info.php?ID=1289606&DL=3906\
# https://www.sgcarmart.com/used_cars/info.php?ID=1298557&DL=2469\
# https://www.sgcarmart.com/used_cars/info.php?ID=1308245&DL=1024\
# https://www.sgcarmart.com/used_cars/info.php?ID=1320557&DL=4524\
# https://www.sgcarmart.com/used_cars/info.php?ID=1322859&DL=1032\
# https://www.sgcarmart.com/used_cars/info.php?ID=1298506&DL=1032\
# https://www.sgcarmart.com/used_cars/info.php?ID=1319257&DL=4031\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334880&DL=2051\
# https://www.sgcarmart.com/used_cars/info.php?ID=1328783&DL=1213\
# https://www.sgcarmart.com/used_cars/info.php?ID=1107163&DL=2356\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332367&DL=4166\
# https://www.sgcarmart.com/used_cars/info.php?ID=1285959&DL=3730\
# https://www.sgcarmart.com/used_cars/info.php?ID=1314130&DL=2578\
# https://www.sgcarmart.com/used_cars/info.php?ID=1318625&DL=4092\
# https://www.sgcarmart.com/used_cars/info.php?ID=1307922&DL=3903\
# https://www.sgcarmart.com/used_cars/info.php?ID=1300262&DL=3382\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335335&DL=3912\
# https://www.sgcarmart.com/used_cars/info.php?ID=1324109&DL=2387\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335000&DL=3570\
# https://www.sgcarmart.com/used_cars/info.php?ID=1241397&DL=4721\
# https://www.sgcarmart.com/used_cars/info.php?ID=1325065&DL=4334\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335522&DL=4108\
# https://www.sgcarmart.com/used_cars/info.php?ID=1323294&DL=3791\
# https://www.sgcarmart.com/used_cars/info.php?ID=1320946&DL=3324\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333011&DL=4659\
# https://www.sgcarmart.com/used_cars/info.php?ID=1315398&DL=3193\
# https://www.sgcarmart.com/used_cars/info.php?ID=1298373&DL=3911\
# https://www.sgcarmart.com/used_cars/info.php?ID=1313893&DL=3981\
# https://www.sgcarmart.com/used_cars/info.php?ID=1328532&DL=1079\
# https://www.sgcarmart.com/used_cars/info.php?ID=1326043&DL=3271\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332639&DL=3613\
# https://www.sgcarmart.com/used_cars/info.php?ID=1274786&DL=2029\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334198&DL=4115\
# https://www.sgcarmart.com/used_cars/info.php?ID=1276107&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331885&DL=1288\
# https://www.sgcarmart.com/used_cars/info.php?ID=1268592&DL=3451\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332815&DL=4721\
# https://www.sgcarmart.com/used_cars/info.php?ID=1336378&DL=4190\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331337&DL=1013\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333196&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1329529&DL=2690\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333751&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1336240&DL=1053\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335203&DL=1213\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332422&DL=2875\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335253&DL=4031\
# https://www.sgcarmart.com/used_cars/info.php?ID=1292020&DL=3989\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333053&DL=4405\
# https://www.sgcarmart.com/used_cars/info.php?ID=1192359&DL=3162\
# https://www.sgcarmart.com/used_cars/info.php?ID=1309591&DL=3405\
# https://www.sgcarmart.com/used_cars/info.php?ID=1315756&DL=3133\
# https://www.sgcarmart.com/used_cars/info.php?ID=1320266&DL=4454\
# https://www.sgcarmart.com/used_cars/info.php?ID=1315368&DL=4428\
# https://www.sgcarmart.com/used_cars/info.php?ID=1328021&DL=2875\
# https://www.sgcarmart.com/used_cars/info.php?ID=1285478&DL=4517\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335356&DL=2875\
# https://www.sgcarmart.com/used_cars/info.php?ID=1285956&DL=3730\
# https://www.sgcarmart.com/used_cars/info.php?ID=1292023&DL=3901\
# https://www.sgcarmart.com/used_cars/info.php?ID=1318719&DL=8008\
# https://www.sgcarmart.com/used_cars/info.php?ID=1307347&DL=2762\
# https://www.sgcarmart.com/used_cars/info.php?ID=1271440&DL=2244\
# https://www.sgcarmart.com/used_cars/info.php?ID=1310587&DL=3894\
# https://www.sgcarmart.com/used_cars/info.php?ID=1315093&DL=2303\
# https://www.sgcarmart.com/used_cars/info.php?ID=1115994&DL=1061\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331392&DL=3570\
# https://www.sgcarmart.com/used_cars/info.php?ID=1328544&DL=4454\
# https://www.sgcarmart.com/used_cars/info.php?ID=1322711&DL=3722\
# https://www.sgcarmart.com/used_cars/info.php?ID=1238498&DL=2339\
# https://www.sgcarmart.com/used_cars/info.php?ID=1317907&DL=3048\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332403&DL=1034\
# https://www.sgcarmart.com/used_cars/info.php?ID=1306337&DL=4667\
# https://www.sgcarmart.com/used_cars/info.php?ID=1314045&DL=3282\
# https://www.sgcarmart.com/used_cars/info.php?ID=1243014&DL=4181\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333891&DL=1163\
# https://www.sgcarmart.com/used_cars/info.php?ID=1308704&DL=8008\
# https://www.sgcarmart.com/used_cars/info.php?ID=1277116&DL=4108\
# https://www.sgcarmart.com/used_cars/info.php?ID=1306080&DL=2397\
# https://www.sgcarmart.com/used_cars/info.php?ID=1203040&DL=3479\
# https://www.sgcarmart.com/used_cars/info.php?ID=1323077&DL=1194\
# https://www.sgcarmart.com/used_cars/info.php?ID=1299577&DL=3730\
# https://www.sgcarmart.com/used_cars/info.php?ID=1304996&DL=2440\
# https://www.sgcarmart.com/used_cars/info.php?ID=1327797&DL=2011\
# https://www.sgcarmart.com/used_cars/info.php?ID=1322014&DL=2410\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332468&DL=1112\
# https://www.sgcarmart.com/used_cars/info.php?ID=1291402&DL=3518\
# https://www.sgcarmart.com/used_cars/info.php?ID=1284173&DL=3811\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335895&DL=2549\
# https://www.sgcarmart.com/used_cars/info.php?ID=1303164&DL=4427\
# https://www.sgcarmart.com/used_cars/info.php?ID=1305730&DL=3648\
# https://www.sgcarmart.com/used_cars/info.php?ID=1231947&DL=2315\
# https://www.sgcarmart.com/used_cars/info.php?ID=1316574&DL=2757\
# https://www.sgcarmart.com/used_cars/info.php?ID=1327953&DL=4343\
# https://www.sgcarmart.com/used_cars/info.php?ID=1313855&DL=4543\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333648&DL=4038\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335964&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1293109&DL=1095\
# https://www.sgcarmart.com/used_cars/info.php?ID=1328854&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1302508&DL=3901\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333871&DL=3648\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335635&DL=3175\
# https://www.sgcarmart.com/used_cars/info.php?ID=1303112&DL=8008\
# https://www.sgcarmart.com/used_cars/info.php?ID=1278876&DL=2875\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330910&DL=2026\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333823&DL=1337\
# https://www.sgcarmart.com/used_cars/info.php?ID=1308509&DL=8008\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332555&DL=4217\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335080&DL=2728\
# https://www.sgcarmart.com/used_cars/info.php?ID=1315393&DL=1351\
# https://www.sgcarmart.com/used_cars/info.php?ID=1318050&DL=3194\
# https://www.sgcarmart.com/used_cars/info.php?ID=1324695&DL=4500\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332921&DL=3597\
# https://www.sgcarmart.com/used_cars/info.php?ID=1314499&DL=2014\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332918&DL=3043\
# https://www.sgcarmart.com/used_cars/info.php?ID=1290934&DL=8008\
# https://www.sgcarmart.com/used_cars/info.php?ID=1336086&DL=3989\
# https://www.sgcarmart.com/used_cars/info.php?ID=1295075&DL=1197\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331727&DL=3863\
# https://www.sgcarmart.com/used_cars/info.php?ID=1289350&DL=1032\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333870&DL=4454\
# https://www.sgcarmart.com/used_cars/info.php?ID=1299446&DL=1194\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334858&DL=1163\
# https://www.sgcarmart.com/used_cars/info.php?ID=1326166&DL=4073\
# https://www.sgcarmart.com/used_cars/info.php?ID=1328939&DL=4612\
# https://www.sgcarmart.com/used_cars/info.php?ID=1282706&DL=3932\
# https://www.sgcarmart.com/used_cars/info.php?ID=1326798&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1295553&DL=1032\
# https://www.sgcarmart.com/used_cars/info.php?ID=1293178&DL=2804\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333767&DL=3486\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331456&DL=3137\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333353&DL=4413\
# https://www.sgcarmart.com/used_cars/info.php?ID=1292778&DL=2469\
# https://www.sgcarmart.com/used_cars/info.php?ID=1252059&DL=2097\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333903&DL=4168\
# https://www.sgcarmart.com/used_cars/info.php?ID=1180784&DL=3554\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335290&DL=2296\
# https://www.sgcarmart.com/used_cars/info.php?ID=1303785&DL=1009\
# https://www.sgcarmart.com/used_cars/info.php?ID=1303191&DL=3757\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332308&DL=3758\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333350&DL=2087\
# https://www.sgcarmart.com/used_cars/info.php?ID=1236907&DL=2239\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330147&DL=2875\
# https://www.sgcarmart.com/used_cars/info.php?ID=1310472&DL=3079\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333357&DL=2163\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335037&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1248849&DL=3137\
# https://www.sgcarmart.com/used_cars/info.php?ID=1321386&DL=4727\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333453&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1322759&DL=2792\
# https://www.sgcarmart.com/used_cars/info.php?ID=1336387&DL=4313\
# https://www.sgcarmart.com/used_cars/info.php?ID=1299089&DL=1177\
# https://www.sgcarmart.com/used_cars/info.php?ID=1328324&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1284789&DL=3989\
# https://www.sgcarmart.com/used_cars/info.php?ID=1312244&DL=4171\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331367&DL=2341\
# https://www.sgcarmart.com/used_cars/info.php?ID=1274799&DL=2855\
# https://www.sgcarmart.com/used_cars/info.php?ID=1336192&DL=1240\
# https://www.sgcarmart.com/used_cars/info.php?ID=1336402&DL=4647\
# https://www.sgcarmart.com/used_cars/info.php?ID=1318565&DL=3452\
# https://www.sgcarmart.com/used_cars/info.php?ID=1311031&DL=1277\
# https://www.sgcarmart.com/used_cars/info.php?ID=1259725&DL=2649\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335078&DL=1240\
# https://www.sgcarmart.com/used_cars/info.php?ID=1155004&DL=2356\
# https://www.sgcarmart.com/used_cars/info.php?ID=1317526&DL=3283\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330478&DL=3626\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330858&DL=4108\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335708&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1296402&DL=3647\
# https://www.sgcarmart.com/used_cars/info.php?ID=1336430&DL=4642\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331034&DL=3133\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330013&DL=2011\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333628&DL=4419\
# https://www.sgcarmart.com/used_cars/info.php?ID=1295407&DL=4386\
# https://www.sgcarmart.com/used_cars/info.php?ID=1241563&DL=2976\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333680&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335313&DL=2351\
# https://www.sgcarmart.com/used_cars/info.php?ID=1327763&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1317303&DL=3541\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331853&DL=1228\
# https://www.sgcarmart.com/used_cars/info.php?ID=1300960&DL=1127\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335846&DL=1000&GAS
# https://www.sgcarmart.com/used_cars/info.php?ID=1334007&DL=3934\
# https://www.sgcarmart.com/used_cars/info.php?ID=1258470&DL=4414\
# https://www.sgcarmart.com/used_cars/info.php?ID=1293860&DL=4078\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331056&DL=3137\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332575&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1298646&DL=2454\
# https://www.sgcarmart.com/used_cars/info.php?ID=1322771&DL=3626\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334543&DL=3142\
# https://www.sgcarmart.com/used_cars/info.php?ID=1312701&DL=4031\
# https://www.sgcarmart.com/used_cars/info.php?ID=1263352&DL=4323\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335536&DL=3142\
# https://www.sgcarmart.com/used_cars/info.php?ID=1293783&DL=4631\
# https://www.sgcarmart.com/used_cars/info.php?ID=1312220&DL=4508\
# https://www.sgcarmart.com/used_cars/info.php?ID=1323592&DL=2126\
# https://www.sgcarmart.com/used_cars/info.php?ID=1318159&DL=4427\
# https://www.sgcarmart.com/used_cars/info.php?ID=1227594&DL=3518\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335556&DL=4721\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335693&DL=3597\
# https://www.sgcarmart.com/used_cars/info.php?ID=1315781&DL=4120\
# https://www.sgcarmart.com/used_cars/info.php?ID=1262493&DL=3706\
# https://www.sgcarmart.com/used_cars/info.php?ID=1313274&DL=2875\
# https://www.sgcarmart.com/used_cars/info.php?ID=1323525&DL=4635\
# https://www.sgcarmart.com/used_cars/info.php?ID=1299793&DL=2080\
# https://www.sgcarmart.com/used_cars/info.php?ID=1299056&DL=1177\
# https://www.sgcarmart.com/used_cars/info.php?ID=1267112&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1316020&DL=2792\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332130&DL=4508\
# https://www.sgcarmart.com/used_cars/info.php?ID=1198398&DL=2448\
# https://www.sgcarmart.com/used_cars/info.php?ID=1329362&DL=2341\
# https://www.sgcarmart.com/used_cars/info.php?ID=1312817&DL=4412\
# https://www.sgcarmart.com/used_cars/info.php?ID=1282250&DL=2339\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335916&DL=2549\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332259&DL=4217\
# https://www.sgcarmart.com/used_cars/info.php?ID=1324856&DL=3627\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330886&DL=4398\
# https://www.sgcarmart.com/used_cars/info.php?ID=1305896&DL=3627\
# https://www.sgcarmart.com/used_cars/info.php?ID=1325131&DL=3426\
# https://www.sgcarmart.com/used_cars/info.php?ID=1316969&DL=1194\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334678&DL=2581\
# https://www.sgcarmart.com/used_cars/info.php?ID=1321915&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335215&DL=511\
# https://www.sgcarmart.com/used_cars/info.php?ID=1288061&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1323300&DL=3570\
# https://www.sgcarmart.com/used_cars/info.php?ID=1312325&DL=3137\
# https://www.sgcarmart.com/used_cars/info.php?ID=1234877&DL=2291\
# https://www.sgcarmart.com/used_cars/info.php?ID=1290209&DL=1111\
# https://www.sgcarmart.com/used_cars/info.php?ID=1313121&DL=2563\
# https://www.sgcarmart.com/used_cars/info.php?ID=1272976&DL=2456\
# https://www.sgcarmart.com/used_cars/info.php?ID=1314134&DL=3321\
# https://www.sgcarmart.com/used_cars/info.php?ID=1325883&DL=2023\
# https://www.sgcarmart.com/used_cars/info.php?ID=1314889&DL=2080\
# https://www.sgcarmart.com/used_cars/info.php?ID=1274544&DL=2511\
# https://www.sgcarmart.com/used_cars/info.php?ID=1328336&DL=3337\
# https://www.sgcarmart.com/used_cars/info.php?ID=874712&DL=2300\
# https://www.sgcarmart.com/used_cars/info.php?ID=1274471&DL=2244\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333416&DL=3838\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335843&DL=2178\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332657&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1220596&DL=3794\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332945&DL=4633\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332283&DL=3597\
# https://www.sgcarmart.com/used_cars/info.php?ID=1299482&DL=4254\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333100&DL=3545\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335617&DL=3831\
# https://www.sgcarmart.com/used_cars/info.php?ID=1311010&DL=1277\
# https://www.sgcarmart.com/used_cars/info.php?ID=1328351&DL=3318\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331491&DL=1307\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334749&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1292208&DL=3298\
# https://www.sgcarmart.com/used_cars/info.php?ID=1178948&DL=3137\
# https://www.sgcarmart.com/used_cars/info.php?ID=1219330&DL=4449\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332444&DL=4741\
# https://www.sgcarmart.com/used_cars/info.php?ID=1267018&DL=2804\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334945&DL=3426\
# https://www.sgcarmart.com/used_cars/info.php?ID=1314349&DL=4286\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332954&DL=3283\
# https://www.sgcarmart.com/used_cars/info.php?ID=1328339&DL=2080\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330219&DL=1107\
# https://www.sgcarmart.com/used_cars/info.php?ID=1297596&DL=4523\
# https://www.sgcarmart.com/used_cars/info.php?ID=1252897&DL=2339\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331194&DL=4073\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335231&DL=3750\
# https://www.sgcarmart.com/used_cars/info.php?ID=1327446&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333206&DL=4473\
# https://www.sgcarmart.com/used_cars/info.php?ID=1298991&DL=1198\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335877&DL=3758\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330822&DL=3750\
# https://www.sgcarmart.com/used_cars/info.php?ID=1327636&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335098&DL=1177\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333292&DL=3647\
# https://www.sgcarmart.com/used_cars/info.php?ID=1325727&DL=3160\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335014&DL=3597\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334809&DL=4604\
# https://www.sgcarmart.com/used_cars/info.php?ID=1325156&DL=3946\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333791&DL=3426\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335629&DL=3934\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335506&DL=3137\
# https://www.sgcarmart.com/used_cars/info.php?ID=1325290&DL=2303\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334003&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1272359&DL=2976\
# https://www.sgcarmart.com/used_cars/info.php?ID=1320736&DL=3368\
# https://www.sgcarmart.com/used_cars/info.php?ID=1207755&DL=1054\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332501&DL=4174\
# https://www.sgcarmart.com/used_cars/info.php?ID=1299086&DL=4612\
# https://www.sgcarmart.com/used_cars/info.php?ID=1323944&DL=4286\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334982&DL=2296\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335214&DL=1311\
# https://www.sgcarmart.com/used_cars/info.php?ID=1237401&DL=4386\
# https://www.sgcarmart.com/used_cars/info.php?ID=1231073&DL=2795\
# https://www.sgcarmart.com/used_cars/info.php?ID=1324961&DL=2655\
# https://www.sgcarmart.com/used_cars/info.php?ID=1311259&DL=4493\
# https://www.sgcarmart.com/used_cars/info.php?ID=1317149&DL=4075\
# https://www.sgcarmart.com/used_cars/info.php?ID=1307997&DL=2029\
# https://www.sgcarmart.com/used_cars/info.php?ID=1286410&DL=2515\
# https://www.sgcarmart.com/used_cars/info.php?ID=1327365&DL=4694\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333151&DL=4555\
# https://www.sgcarmart.com/used_cars/info.php?ID=1322636&DL=2003\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332637&DL=3122\
# https://www.sgcarmart.com/used_cars/info.php?ID=1326025&DL=4453\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333550&DL=2311\
# https://www.sgcarmart.com/used_cars/info.php?ID=1312392&DL=2080\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335967&DL=4337\
# https://www.sgcarmart.com/used_cars/info.php?ID=1327164&DL=4454\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330365&DL=3043\
# https://www.sgcarmart.com/used_cars/info.php?ID=1267416&DL=4140\
# https://www.sgcarmart.com/used_cars/info.php?ID=1323142&DL=1360\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334757&DL=4327\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332775&DL=4277\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335351&DL=3259\
# https://www.sgcarmart.com/used_cars/info.php?ID=1316947&DL=4114\
# https://www.sgcarmart.com/used_cars/info.php?ID=1311837&DL=2913\
# https://www.sgcarmart.com/used_cars/info.php?ID=1315542&DL=3163\
# https://www.sgcarmart.com/used_cars/info.php?ID=1307699&DL=4378\
# https://www.sgcarmart.com/used_cars/info.php?ID=1315127&DL=2578\
# https://www.sgcarmart.com/used_cars/info.php?ID=1328701&DL=3283\
# https://www.sgcarmart.com/used_cars/info.php?ID=1308932&DL=1079\
# https://www.sgcarmart.com/used_cars/info.php?ID=1301378&DL=3043\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335108&DL=3318\
# https://www.sgcarmart.com/used_cars/info.php?ID=1292733&DL=4505\
# https://www.sgcarmart.com/used_cars/info.php?ID=1291518&DL=3318\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335271&DL=4555\
# https://www.sgcarmart.com/used_cars/info.php?ID=1308830&DL=2943\
# https://www.sgcarmart.com/used_cars/info.php?ID=1258374&DL=2493\
# https://www.sgcarmart.com/used_cars/info.php?ID=1271942&DL=3414\
# https://www.sgcarmart.com/used_cars/info.php?ID=1293811&DL=1258\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335541&DL=1368\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331061&DL=4523\
# https://www.sgcarmart.com/used_cars/info.php?ID=1336394&DL=4717\
# https://www.sgcarmart.com/used_cars/info.php?ID=1226296&DL=3541\
# https://www.sgcarmart.com/used_cars/info.php?ID=1291766&DL=3648\
# https://www.sgcarmart.com/used_cars/info.php?ID=1336039&DL=4630\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334506&DL=3359\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332294&DL=1001\
# https://www.sgcarmart.com/used_cars/info.php?ID=1329154&DL=1240\
# https://www.sgcarmart.com/used_cars/info.php?ID=1294962&DL=3318\
# https://www.sgcarmart.com/used_cars/info.php?ID=1324997&DL=1136\
# https://www.sgcarmart.com/used_cars/info.php?ID=1247890&DL=3837\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332856&DL=2239\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335662&DL=1311\
# https://www.sgcarmart.com/used_cars/info.php?ID=1193400&DL=2757\
# https://www.sgcarmart.com/used_cars/info.php?ID=1218629&DL=3901\
# https://www.sgcarmart.com/used_cars/info.php?ID=1294071&DL=2051\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334844&DL=2762\
# https://www.sgcarmart.com/used_cars/info.php?ID=1312846&DL=2291\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332018&DL=4014\
# https://www.sgcarmart.com/used_cars/info.php?ID=1316705&DL=4309\
# https://www.sgcarmart.com/used_cars/info.php?ID=1322514&DL=1245\
# https://www.sgcarmart.com/used_cars/info.php?ID=1315852&DL=2655\
# https://www.sgcarmart.com/used_cars/info.php?ID=1327262&DL=4694\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335834&DL=4458\
# https://www.sgcarmart.com/used_cars/info.php?ID=1306460&DL=1198\
# https://www.sgcarmart.com/used_cars/info.php?ID=1274158&DL=3989\
# https://www.sgcarmart.com/used_cars/info.php?ID=1328937&DL=4405\
# https://www.sgcarmart.com/used_cars/info.php?ID=1318034&DL=1351\
# https://www.sgcarmart.com/used_cars/info.php?ID=1313978&DL=3545\
# https://www.sgcarmart.com/used_cars/info.php?ID=1281422&DL=1135\
# https://www.sgcarmart.com/used_cars/info.php?ID=1306587&DL=2943\
# https://www.sgcarmart.com/used_cars/info.php?ID=1261189&DL=3456\
# https://www.sgcarmart.com/used_cars/info.php?ID=1317147&DL=1213\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335576&DL=3269\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334842&DL=3426\
# https://www.sgcarmart.com/used_cars/info.php?ID=1315498&DL=2291\
# https://www.sgcarmart.com/used_cars/info.php?ID=1313068&DL=3665\
# https://www.sgcarmart.com/used_cars/info.php?ID=1310806&DL=1238\
# https://www.sgcarmart.com/used_cars/info.php?ID=1277981&DL=4405\
# https://www.sgcarmart.com/used_cars/info.php?ID=1228946&DL=3350\
# https://www.sgcarmart.com/used_cars/info.php?ID=1310421&DL=2469\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331996&DL=1047\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333902&DL=3570\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331652&DL=1193\
# https://www.sgcarmart.com/used_cars/info.php?ID=1322883&DL=3486\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332597&DL=3137\
# https://www.sgcarmart.com/used_cars/info.php?ID=1326276&DL=3133\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333588&DL=3004\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335919&DL=2239\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335508&DL=3602\
# https://www.sgcarmart.com/used_cars/info.php?ID=1328704&DL=3214\
# https://www.sgcarmart.com/used_cars/info.php?ID=1301370&DL=4286\
# https://www.sgcarmart.com/used_cars/info.php?ID=1313678&DL=1144\
# https://www.sgcarmart.com/used_cars/info.php?ID=1306812&DL=1400\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334089&DL=3414\
# https://www.sgcarmart.com/used_cars/info.php?ID=1238735&DL=4332\
# https://www.sgcarmart.com/used_cars/info.php?ID=1292713&DL=4419\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335784&DL=3647\
# https://www.sgcarmart.com/used_cars/info.php?ID=1324881&DL=3452\
# https://www.sgcarmart.com/used_cars/info.php?ID=1192998&DL=2025\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332408&DL=2341\
# https://www.sgcarmart.com/used_cars/info.php?ID=1250746&DL=3137\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331513&DL=3368\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334184&DL=4631\
# https://www.sgcarmart.com/used_cars/info.php?ID=1283115&DL=2469\
# https://www.sgcarmart.com/used_cars/info.php?ID=1327777&DL=1213\
# https://www.sgcarmart.com/used_cars/info.php?ID=1308525&DL=3975\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333986&DL=3426\
# https://www.sgcarmart.com/used_cars/info.php?ID=1288174&DL=4523\
# https://www.sgcarmart.com/used_cars/info.php?ID=1294557&DL=4125\
# https://www.sgcarmart.com/used_cars/info.php?ID=1323050&DL=4114\
# https://www.sgcarmart.com/used_cars/info.php?ID=1308939&DL=3911\
# https://www.sgcarmart.com/used_cars/info.php?ID=1317484&DL=4075\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334432&DL=3283\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335307&DL=4668\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332727&DL=4108\
# https://www.sgcarmart.com/used_cars/info.php?ID=1311334&DL=3133\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333575&DL=2345\
# https://www.sgcarmart.com/used_cars/info.php?ID=1238727&DL=3507\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335737&DL=4543\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334346&DL=2397\
# https://www.sgcarmart.com/used_cars/info.php?ID=1323845&DL=4056\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335739&DL=3381\
# https://www.sgcarmart.com/used_cars/info.php?ID=1313813&DL=3452\
# https://www.sgcarmart.com/used_cars/info.php?ID=1312898&DL=4074\
# https://www.sgcarmart.com/used_cars/info.php?ID=1315297&DL=1127\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334290&DL=4543\
# https://www.sgcarmart.com/used_cars/info.php?ID=1326027&DL=4592\
# https://www.sgcarmart.com/used_cars/info.php?ID=1312031&DL=4111\
# https://www.sgcarmart.com/used_cars/info.php?ID=1325485&DL=3318\
# https://www.sgcarmart.com/used_cars/info.php?ID=1314530&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335448&DL=1198\
# https://www.sgcarmart.com/used_cars/info.php?ID=1298010&DL=4442\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333058&DL=4298\
# https://www.sgcarmart.com/used_cars/info.php?ID=1299991&DL=3283&utm_content=SLeligible\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334701&DL=4391\
# https://www.sgcarmart.com/used_cars/info.php?ID=1241808&DL=2976\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330134&DL=3570\
# https://www.sgcarmart.com/used_cars/info.php?ID=1324645&DL=1213\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333822&DL=4365\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334035&DL=2659\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333518&DL=2757\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332116&DL=2875\
# https://www.sgcarmart.com/used_cars/info.php?ID=1219414&DL=3712\
# https://www.sgcarmart.com/used_cars/info.php?ID=1313293&DL=1079\
# https://www.sgcarmart.com/used_cars/info.php?ID=1165349&DL=1177\
# https://www.sgcarmart.com/used_cars/info.php?ID=1328103&DL=3137\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333172&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1299201&DL=2434\
# https://www.sgcarmart.com/used_cars/info.php?ID=1209703&DL=8008\
# https://www.sgcarmart.com/used_cars/info.php?ID=1327157&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332129&DL=4189\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334476&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1315106&DL=4671\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334651&DL=3175\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332276&DL=3597\
# https://www.sgcarmart.com/used_cars/info.php?ID=1296093&DL=1277\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333286&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1320649&DL=2080\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334115&DL=2943\
# https://www.sgcarmart.com/used_cars/info.php?ID=1262931&DL=2754\
# https://www.sgcarmart.com/used_cars/info.php?ID=1312394&DL=4346\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334203&DL=4601\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333432&DL=4385\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335440&DL=2875\
# https://www.sgcarmart.com/used_cars/info.php?ID=1320754&DL=4073\
# https://www.sgcarmart.com/used_cars/info.php?ID=1294150&DL=2725\
# https://www.sgcarmart.com/used_cars/info.php?ID=1260322&DL=2080\
# https://www.sgcarmart.com/used_cars/info.php?ID=1326614&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332306&DL=4574\
# https://www.sgcarmart.com/used_cars/info.php?ID=1336102&DL=3758\
# https://www.sgcarmart.com/used_cars/info.php?ID=1311446&DL=3981\
# https://www.sgcarmart.com/used_cars/info.php?ID=1318533&DL=2389\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330187&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1314095&DL=3546\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334296&DL=2626\
# https://www.sgcarmart.com/used_cars/info.php?ID=1243332&DL=4523\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333443&DL=2655\
# https://www.sgcarmart.com/used_cars/info.php?ID=1272476&DL=1353\
# https://www.sgcarmart.com/used_cars/info.php?ID=1257685&DL=1094\
# https://www.sgcarmart.com/used_cars/info.php?ID=1321563&DL=3648\
# https://www.sgcarmart.com/used_cars/info.php?ID=1329149&DL=1350\
# https://www.sgcarmart.com/used_cars/info.php?ID=1269093&DL=3791\
# https://www.sgcarmart.com/used_cars/info.php?ID=1295164&DL=1079\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334513&DL=1264\
# https://www.sgcarmart.com/used_cars/info.php?ID=1322002&DL=1351\
# https://www.sgcarmart.com/used_cars/info.php?ID=1329058&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333640&DL=4419\
# https://www.sgcarmart.com/used_cars/info.php?ID=1336017&DL=4744\
# https://www.sgcarmart.com/used_cars/info.php?ID=1323178&DL=2303\
# https://www.sgcarmart.com/used_cars/info.php?ID=1311140&DL=1001\
# https://www.sgcarmart.com/used_cars/info.php?ID=1321848&DL=4638\
# https://www.sgcarmart.com/used_cars/info.php?ID=1288575&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1215061&DL=23
# https://www.sgcarmart.com/used_cars/info.php?ID=1324636&DL=1013\
# https://www.sgcarmart.com/used_cars/info.php?ID=1327651&DL=4689\
# https://www.sgcarmart.com/used_cars/info.php?ID=1336046&DL=3989\
# https://www.sgcarmart.com/used_cars/info.php?ID=1244501&DL=2976\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332658&DL=4098\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334375&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332674&DL=2140\
# https://www.sgcarmart.com/used_cars/info.php?ID=1316407&DL=3718\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335039&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1305312&DL=1418\
# https://www.sgcarmart.com/used_cars/info.php?ID=1315346&DL=4300\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330232&DL=4523\
# https://www.sgcarmart.com/used_cars/info.php?ID=1238877&DL=4120\
# https://www.sgcarmart.com/used_cars/info.php?ID=1304175&DL=2804\
# https://www.sgcarmart.com/used_cars/info.php?ID=1302416&DL=3043\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334723&DL=3545\
# https://www.sgcarmart.com/used_cars/info.php?ID=1308756&DL=1213\
# https://www.sgcarmart.com/used_cars/info.php?ID=1300272&DL=3451\
# https://www.sgcarmart.com/used_cars/info.php?ID=1329532&DL=1193\
# https://www.sgcarmart.com/used_cars/info.php?ID=1326500&DL=3712\
# https://www.sgcarmart.com/used_cars/info.php?ID=1316385&DL=2473\
# https://www.sgcarmart.com/used_cars/info.php?ID=1324424&DL=1090\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335854&DL=3142\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335650&DL=3043\
# https://www.sgcarmart.com/used_cars/info.php?ID=1327549&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1314324&DL=2008\
# https://www.sgcarmart.com/used_cars/info.php?ID=1307378&DL=1344\
# https://www.sgcarmart.com/used_cars/info.php?ID=1222048&DL=3451\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332144&DL=1034\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333113&DL=1177\
# https://www.sgcarmart.com/used_cars/info.php?ID=1322366&DL=2650\
# https://www.sgcarmart.com/used_cars/info.php?ID=1273141&DL=2008\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334070&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1213438&DL=3976\
# https://www.sgcarmart.com/used_cars/info.php?ID=1310865&DL=3730\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332137&DL=3626\
# https://www.sgcarmart.com/used_cars/info.php?ID=1308057&DL=4494\
# https://www.sgcarmart.com/used_cars/info.php?ID=1326109&DL=3801\
# https://www.sgcarmart.com/used_cars/info.php?ID=1151452&DL=1061\
# https://www.sgcarmart.com/used_cars/info.php?ID=1276326&DL=4343\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332347&DL=1172\
# https://www.sgcarmart.com/used_cars/info.php?ID=1308861&DL=3393\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335717&DL=3597\
# https://www.sgcarmart.com/used_cars/info.php?ID=1298971&DL=2969\
# https://www.sgcarmart.com/used_cars/info.php?ID=1307554&DL=2965\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333929&DL=4731\
# https://www.sgcarmart.com/used_cars/info.php?ID=1317678&DL=1360\
# https://www.sgcarmart.com/used_cars/info.php?ID=1325011&DL=2428\
# https://www.sgcarmart.com/used_cars/info.php?ID=1329293&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332328&DL=1028\
# https://www.sgcarmart.com/used_cars/info.php?ID=1307786&DL=4234\
# https://www.sgcarmart.com/used_cars/info.php?ID=1268142&DL=3142\
# https://www.sgcarmart.com/used_cars/info.php?ID=1324066&DL=3757\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335461&DL=3301\
# https://www.sgcarmart.com/used_cars/info.php?ID=1314773&DL=2469\
# https://www.sgcarmart.com/used_cars/info.php?ID=1279487&DL=4508\
# https://www.sgcarmart.com/used_cars/info.php?ID=1297346&DL=1106\
# https://www.sgcarmart.com/used_cars/info.php?ID=1321565&DL=2976\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334953&DL=1032\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334046&DL=1136\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334130&DL=2303\
# ...
# https://www.sgcarmart.com/used_cars/info.php?ID=1332563&DL=4398\
# https://www.sgcarmart.com/used_cars/info.php?ID=1247437&DL=1034\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334470&DL=3518\
# https://www.sgcarmart.com/used_cars/info.php?ID=1320714&DL=4228\
# https://www.sgcarmart.com/used_cars/info.php?ID=1314908&DL=3832\
# https://www.sgcarmart.com/used_cars/info.php?ID=1218137&DL=2976\
# https://www.sgcarmart.com/used_cars/info.php?ID=1307442&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1254449&DL=1189\
# https://www.sgcarmart.com/used_cars/info.php?ID=1315326&DL=1095\
# https://www.sgcarmart.com/used_cars/info.php?ID=1275157&DL=4461\
# https://www.sgcarmart.com/used_cars/info.php?ID=1273665&DL=1189\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335262&DL=3758&utm_content=SLeligible\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333393&DL=3758\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335236&DL=3271\
# https://www.sgcarmart.com/used_cars/info.php?ID=1278510&DL=4635\
# https://www.sgcarmart.com/used_cars/info.php?ID=1283974&DL=3792\
# https://www.sgcarmart.com/used_cars/info.php?ID=1316174&DL=3730\
# https://www.sgcarmart.com/used_cars/info.php?ID=1322820&DL=4453\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334040&DL=4286\
# https://www.sgcarmart.com/used_cars/info.php?ID=1322777&DL=4154\
# https://www.sgcarmart.com/used_cars/info.php?ID=1303366&DL=3427\
# https://www.sgcarmart.com/used_cars/info.php?ID=1313166&DL=1043\
# https://www.sgcarmart.com/used_cars/info.php?ID=1329802&DL=3259\
# https://www.sgcarmart.com/used_cars/info.php?ID=1327204&DL=3613\
# https://www.sgcarmart.com/used_cars/info.php?ID=1203516&DL=2448\
# https://www.sgcarmart.com/used_cars/info.php?ID=1296169&DL=1010\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330501&DL=8008\
# https://www.sgcarmart.com/used_cars/info.php?ID=1315437&DL=1144\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334902&DL=4073\
# https://www.sgcarmart.com/used_cars/info.php?ID=1293660&DL=3283\
# https://www.sgcarmart.com/used_cars/info.php?ID=1252510&DL=2291\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332460&DL=4592\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334116&DL=1164\
# https://www.sgcarmart.com/used_cars/info.php?ID=1292458&DL=2010\
# https://www.sgcarmart.com/used_cars/info.php?ID=1326613&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1248146&DL=1277\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335580&DL=3887\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335494&DL=3648\
# https://www.sgcarmart.com/used_cars/info.php?ID=1320975&DL=3800\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332101&DL=4558\
# https://www.sgcarmart.com/used_cars/info.php?ID=1288442&DL=3727\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330764&DL=2163\
# https://www.sgcarmart.com/used_cars/info.php?ID=1309384&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1305294&DL=2049\
# https://www.sgcarmart.com/used_cars/info.php?ID=1308786&DL=2757\
# https://www.sgcarmart.com/used_cars/info.php?ID=1293204&DL=3627\
# https://www.sgcarmart.com/used_cars/info.php?ID=1262849&DL=2849\
# https://www.sgcarmart.com/used_cars/info.php?ID=1316091&DL=3846\
# https://www.sgcarmart.com/used_cars/info.php?ID=1254750&DL=1106\
# https://www.sgcarmart.com/used_cars/info.php?ID=1299189&DL=3718\
# https://www.sgcarmart.com/used_cars/info.php?ID=1311437&DL=4031\
# https://www.sgcarmart.com/used_cars/info.php?ID=1321578&DL=4647\
# https://www.sgcarmart.com/used_cars/info.php?ID=1313730&DL=3758\
# https://www.sgcarmart.com/used_cars/info.php?ID=1314261&DL=3382\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331469&DL=4412\
# https://www.sgcarmart.com/used_cars/info.php?ID=1300271&DL=3452\
# https://www.sgcarmart.com/used_cars/info.php?ID=1312086&DL=3932\
# https://www.sgcarmart.com/used_cars/info.php?ID=1308419&DL=4645\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334736&DL=3597\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334263&DL=3590\
# https://www.sgcarmart.com/used_cars/info.php?ID=1310189&DL=3587\
# https://www.sgcarmart.com/used_cars/info.php?ID=1288844&DL=3133\
# https://www.sgcarmart.com/used_cars/info.php?ID=1329292&DL=2757\
# https://www.sgcarmart.com/used_cars/info.php?ID=1314327&DL=4383\
# https://www.sgcarmart.com/used_cars/info.php?ID=1324347&DL=2900\
# https://www.sgcarmart.com/used_cars/info.php?ID=1318809&DL=1281\
# https://www.sgcarmart.com/used_cars/info.php?ID=1286903&DL=4628\
# https://www.sgcarmart.com/used_cars/info.php?ID=1282532&DL=4108\
# https://www.sgcarmart.com/used_cars/info.php?ID=1276354&DL=3727\
# https://www.sgcarmart.com/used_cars/info.php?ID=1328631&DL=4061\
# https://www.sgcarmart.com/used_cars/info.php?ID=1323186&DL=2303\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330815&DL=4561\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335378&DL=8008\
# https://www.sgcarmart.com/used_cars/info.php?ID=1205497&DL=2410\
# https://www.sgcarmart.com/used_cars/info.php?ID=1318438&DL=2339\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332979&DL=3414\
# https://www.sgcarmart.com/used_cars/info.php?ID=1325696&DL=3318\
# https://www.sgcarmart.com/used_cars/info.php?ID=1319624&DL=4309\
# https://www.sgcarmart.com/used_cars/info.php?ID=1325728&DL=2093\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332755&DL=2885\
# https://www.sgcarmart.com/used_cars/info.php?ID=1249806&DL=3723\
# https://www.sgcarmart.com/used_cars/info.php?ID=1290012&DL=2356\
# https://www.sgcarmart.com/used_cars/info.php?ID=1314264&DL=4108\
# https://www.sgcarmart.com/used_cars/info.php?ID=1257455&DL=3989\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335608&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1317400&DL=2303\
# https://www.sgcarmart.com/used_cars/info.php?ID=1336417&DL=2702\
# https://www.sgcarmart.com/used_cars/info.php?ID=1300484&DL=3750\
# https://www.sgcarmart.com/used_cars/info.php?ID=1336034&DL=3727\
# https://www.sgcarmart.com/used_cars/info.php?ID=1312735&DL=2080\
# https://www.sgcarmart.com/used_cars/info.php?ID=1312280&DL=4419\
# https://www.sgcarmart.com/used_cars/info.php?ID=1308293&DL=3722\
# https://www.sgcarmart.com/used_cars/info.php?ID=1325087&DL=2875\
# https://www.sgcarmart.com/used_cars/info.php?ID=1325215&DL=3838\
# https://www.sgcarmart.com/used_cars/info.php?ID=1312081&DL=2049\
# https://www.sgcarmart.com/used_cars/info.php?ID=1319042&DL=3415\
# https://www.sgcarmart.com/used_cars/info.php?ID=1202734&DL=1188\
# https://www.sgcarmart.com/used_cars/info.php?ID=1250213&DL=4277\
# https://www.sgcarmart.com/used_cars/info.php?ID=1324705&DL=2969&utm_content=SLeligible\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335653&DL=2783\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335727&DL=3175\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333623&DL=4737\
# https://www.sgcarmart.com/used_cars/info.php?ID=1322185&DL=1001\
# https://www.sgcarmart.com/used_cars/info.php?ID=1255720&DL=3730\
# https://www.sgcarmart.com/used_cars/info.php?ID=1320059&DL=2291\
# https://www.sgcarmart.com/used_cars/info.php?ID=1322539&DL=1213\
# https://www.sgcarmart.com/used_cars/info.php?ID=1314082&DL=1194\
# https://www.sgcarmart.com/used_cars/info.php?ID=1293955&DL=1163\
# https://www.sgcarmart.com/used_cars/info.php?ID=1302130&DL=4523\
# https://www.sgcarmart.com/used_cars/info.php?ID=1292330&DL=3163\
# https://www.sgcarmart.com/used_cars/info.php?ID=1299277&DL=2493\
# https://www.sgcarmart.com/used_cars/info.php?ID=1315978&DL=4550\
# https://www.sgcarmart.com/used_cars/info.php?ID=1310682&DL=8008\
# https://www.sgcarmart.com/used_cars/info.php?ID=1319398&DL=4412\
# https://www.sgcarmart.com/used_cars/info.php?ID=1304869&DL=3214\
# https://www.sgcarmart.com/used_cars/info.php?ID=1311709&DL=2189\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332837&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335137&DL=4645\
# https://www.sgcarmart.com/used_cars/info.php?ID=1244391&DL=2804\
# https://www.sgcarmart.com/used_cars/info.php?ID=1295047&DL=2296\
# https://www.sgcarmart.com/used_cars/info.php?ID=1121515&DL=1220\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331152&DL=3750\
# https://www.sgcarmart.com/used_cars/info.php?ID=1325962&DL=4508\
# https://www.sgcarmart.com/used_cars/info.php?ID=1253859&DL=4557\
# https://www.sgcarmart.com/used_cars/info.php?ID=1329086&DL=2875\
# https://www.sgcarmart.com/used_cars/info.php?ID=1336064&DL=3597\
# https://www.sgcarmart.com/used_cars/info.php?ID=1327799&DL=4064\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335917&DL=2239\
# https://www.sgcarmart.com/used_cars/info.php?ID=1322566&DL=2493\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332175&DL=2201\
# https://www.sgcarmart.com/used_cars/info.php?ID=1323269&DL=3791\
# https://www.sgcarmart.com/used_cars/info.php?ID=1322481&DL=3100\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335735&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331755&DL=1418\
# https://www.sgcarmart.com/used_cars/info.php?ID=1311358&DL=8008\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332126&DL=3912\
# https://www.sgcarmart.com/used_cars/info.php?ID=1328201&DL=4064\
# https://www.sgcarmart.com/used_cars/info.php?ID=1326581&DL=3887\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332547&DL=4362\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335633&DL=3758\
# https://www.sgcarmart.com/used_cars/info.php?ID=1240704&DL=1034\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335975&DL=4672\
# https://www.sgcarmart.com/used_cars/info.php?ID=1304244&DL=2389\
# https://www.sgcarmart.com/used_cars/info.php?ID=1317537&DL=3137\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333021&DL=3597\
# https://www.sgcarmart.com/used_cars/info.php?ID=1336361&DL=1034\
# https://www.sgcarmart.com/used_cars/info.php?ID=1308831&DL=2129\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334595&DL=3602\
# https://www.sgcarmart.com/used_cars/info.php?ID=1325552&DL=2029\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332723&DL=4189\
# https://www.sgcarmart.com/used_cars/info.php?ID=1312815&DL=2239\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335773&DL=3456\
# https://www.sgcarmart.com/used_cars/info.php?ID=1313401&DL=3283\
# https://www.sgcarmart.com/used_cars/info.php?ID=1287348&DL=1054\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334453&DL=1136\
# https://www.sgcarmart.com/used_cars/info.php?ID=1313688&DL=2650\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332435&DL=4210\
# https://www.sgcarmart.com/used_cars/info.php?ID=1323347&DL=4721\
# https://www.sgcarmart.com/used_cars/info.php?ID=1292715&DL=4293\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332407&DL=2352\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333522&DL=4038\
# https://www.sgcarmart.com/used_cars/info.php?ID=1313459&DL=2944\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332181&DL=4624\
# https://www.sgcarmart.com/used_cars/info.php?ID=1305100&DL=2011\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334076&DL=3382\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331880&DL=3214\
# https://www.sgcarmart.com/used_cars/info.php?ID=1322457&DL=3495\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333965&DL=4343\
# https://www.sgcarmart.com/used_cars/info.php?ID=1287697&DL=3722\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332718&DL=4343\
# https://www.sgcarmart.com/used_cars/info.php?ID=1316426&DL=3597\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334787&DL=2014\
# https://www.sgcarmart.com/used_cars/info.php?ID=1328811&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334443&DL=2473\
# https://www.sgcarmart.com/used_cars/info.php?ID=1306194&DL=3318\
# https://www.sgcarmart.com/used_cars/info.php?ID=1202195&DL=2096\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333014&DL=3597\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331644&DL=8008\
# https://www.sgcarmart.com/used_cars/info.php?ID=1322826&DL=2714\
# https://www.sgcarmart.com/used_cars/info.php?ID=1312216&DL=1135\
# https://www.sgcarmart.com/used_cars/info.php?ID=1329553&DL=2454\
# https://www.sgcarmart.com/used_cars/info.php?ID=1302596&DL=2473\
# https://www.sgcarmart.com/used_cars/info.php?ID=1327491&DL=4465\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335178&DL=4038\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334532&DL=1354\
# https://www.sgcarmart.com/used_cars/info.php?ID=1258508&DL=2493\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332092&DL=1354\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335671&DL=1311\
# https://www.sgcarmart.com/used_cars/info.php?ID=1319132&DL=3791\
# https://www.sgcarmart.com/used_cars/info.php?ID=1326919&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1300941&DL=3426\
# https://www.sgcarmart.com/used_cars/info.php?ID=1272908&DL=1368\
# https://www.sgcarmart.com/used_cars/info.php?ID=997154&DL=3579\
# https://www.sgcarmart.com/used_cars/info.php?ID=1313178&DL=2200\
# https://www.sgcarmart.com/used_cars/info.php?ID=1324245&DL=4465\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335279&DL=3133\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331637&DL=2341\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333051&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1291858&DL=3846\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335758&DL=3387\
# https://www.sgcarmart.com/used_cars/info.php?ID=1325882&DL=2870\
# https://www.sgcarmart.com/used_cars/info.php?ID=1297743&DL=3721\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332470&DL=2341\
# https://www.sgcarmart.com/used_cars/info.php?ID=1320506&DL=4327\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335046&DL=2163\
# https://www.sgcarmart.com/used_cars/info.php?ID=1313090&DL=1127\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333982&DL=2984\
# https://www.sgcarmart.com/used_cars/info.php?ID=1184215&DL=3973\
# https://www.sgcarmart.com/used_cars/info.php?ID=1286538&DL=3546\
# https://www.sgcarmart.com/used_cars/info.php?ID=1336314&DL=4412\
# https://www.sgcarmart.com/used_cars/info.php?ID=1248356&DL=3730\
# https://www.sgcarmart.com/used_cars/info.php?ID=1327744&DL=2434\
# https://www.sgcarmart.com/used_cars/info.php?ID=1325443&DL=3894\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334120&DL=1368\
# https://www.sgcarmart.com/used_cars/info.php?ID=1299545&DL=3283\
# https://www.sgcarmart.com/used_cars/info.php?ID=1314950&DL=3508\
# https://www.sgcarmart.com/used_cars/info.php?ID=1278486&DL=2793\
# https://www.sgcarmart.com/used_cars/info.php?ID=1225572&DL=2689\
# https://www.sgcarmart.com/used_cars/info.php?ID=1326493&DL=3906\
# https://www.sgcarmart.com/used_cars/info.php?ID=1257258&DL=4364\
# https://www.sgcarmart.com/used_cars/info.php?ID=1318868&DL=3381\
# https://www.sgcarmart.com/used_cars/info.php?ID=1327145&DL=1163\
# https://www.sgcarmart.com/used_cars/info.php?ID=1322215&DL=1195\
# https://www.sgcarmart.com/used_cars/info.php?ID=1322347&DL=2291\
# https://www.sgcarmart.com/used_cars/info.php?ID=1312676&DL=3283\
# https://www.sgcarmart.com/used_cars/info.php?ID=1333067&DL=4450\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334905&DL=1344\
# https://www.sgcarmart.com/used_cars/info.php?ID=1335480&DL=2389\
# https://www.sgcarmart.com/used_cars/info.php?ID=1289560&DL=2976\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334429&DL=1054\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332587&DL=3758\
# https://www.sgcarmart.com/used_cars/info.php?ID=1280664&DL=2356\
# https://www.sgcarmart.com/used_cars/info.php?ID=1317733&DL=1155\
# https://www.sgcarmart.com/used_cars/info.php?ID=1305102&DL=1090\
# https://www.sgcarmart.com/used_cars/info.php?ID=1332867&DL=3175\
# https://www.sgcarmart.com/used_cars/info.php?ID=1258223&DL=2448\
# https://www.sgcarmart.com/used_cars/info.php?ID=1336008&DL=3518\
# https://www.sgcarmart.com/used_cars/info.php?ID=1334960&DL=1079\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330678&DL=2804\
# https://www.sgcarmart.com/used_cars/info.php?ID=1330285&DL=1000\
# https://www.sgcarmart.com/used_cars/info.php?ID=1308819&DL=3626\
# https://www.sgcarmart.com/used_cars/info.php?ID=1299355&DL=3837\
# https://www.sgcarmart.com/used_cars/info.php?ID=1275364&DL=4157\
# https://www.sgcarmart.com/used_cars/info.php?ID=1278267&DL=8008\
# https://www.sgcarmart.com/used_cars/info.php?ID=1331908&DL=2953\

# %%
print(len(listing_urls))
#print(len(set(listing_urls)))
#print(len(list(set(listing_urls))))
# Out:
# 9926
# 9926
# 9926

# %%
import csv

def save_urls_to_csv(listing_urls, filename='listing_urls.csv'):
    """
    Save a list of URLs to a CSV file with an index.

    Parameters:
    listing_urls (list): List of URLs to save.
    filename (str): The name of the CSV file. Default is 'listing_urls.csv'.
    """
    with open(filename, 'w', newline='') as csvfile:
        csvwriter = csv.writer(csvfile)
        csvwriter.writerow(['Index', 'URL'])  # Write the header
        for index, url in enumerate(listing_urls, start=1):
            csvwriter.writerow([index, url])
    print(f"Links have been saved to {filename} with indices")

# %%
save_urls_to_csv(listing_urls)
# Out:
# Links have been saved to listing_urls.csv with indices

# %%
print(listing_urls[:10])
# Out:
# ['https://www.sgcarmart.com/used_cars/info.php?ID=1293490&DL=4524\\', 'https://www.sgcarmart.com/used_cars/info.php?ID=1335107&DL=2876\\', 'https://www.sgcarmart.com/used_cars/info.php?ID=1319958&DL=1188\\', 'https://www.sgcarmart.com/used_cars/info.php?ID=1335957&DL=4014\\', 'https://www.sgcarmart.com/used_cars/info.php?ID=1319609&DL=2875\\', 'https://www.sgcarmart.com/used_cars/info.php?ID=1317859&DL=4516\\', 'https://www.sgcarmart.com/used_cars/info.php?ID=1336144&DL=2547\\', 'https://www.sgcarmart.com/used_cars/info.php?ID=1333407&DL=1136\\', 'https://www.sgcarmart.com/used_cars/info.php?ID=1238413&DL=2958\\', 'https://www.sgcarmart.com/used_cars/info.php?ID=1310552&DL=4731\\']

# %% [markdown]
# ## 6. Create DataFrame

# %% [markdown]
# def scrape_car_data(listing_urls, filename='sgcarmart_used_cars_prices'):
#     """
#     Scrapes car data from the provided list of listing URLs and saves the data to a CSV file.
#
#     Parameters:
#     listing_urls (list): A list of URLs for the individual car listings.
#     filename (str, optional): The name of the output CSV file (without the .csv extension). Defaults to 'sgcarmart_used_cars_prices'.
#     """
#     # Creating an empty DataFrame for attributes of interest
#     df = pd.DataFrame(columns=[
#         'LISTING_URL', 'BRAND', 'PRICE', 'DEPRE_YEARLY', 'REG_DATE', 'MILEAGE_KM',
#         'MANUFACTURED_YEAR', 'ROAD_TAX_YEARLY', 'TRANSMISSION', 'DEREG_VALUE_FROM_SCRAPE_DATE',
#         'SCRAPE_DATE', 'OMV', 'ARF', 'COE_FROM_SCRAPE_DATE', 'DAYS_OF_COE_LEFT',
#         'ENGINE_CAPACITY_CC', 'CURB_WEIGHT_KG', 'NO_OF_OWNERS', 'VEHICLE_TYPE', 'FUEL_TYPE'
#     ])
#
#     i = 0 # Indexing rows in the DF
#     for i, listingurl in enumerate(listing_urls):
#         response = requests.get(listingurl)
#         listing_url = BeautifulSoup(response.text, 'lxml')
#
#         df.loc[i, 'LISTING_URL'] = listingurl
#         df.loc[i, 'BRAND'] = brand_retrieval(listing_url)
#         df.loc[i, 'PRICE'] = price_retrieval(listing_url)
#         df.loc[i, 'DEPRE_YEARLY'] = depreciation_yearly_retrieval(listing_url)
#         df.loc[i, 'REG_DATE'] = reg_date_retrieval(listing_url)
#         df.loc[i, 'MILEAGE_KM'] = mileage_retrieval(listing_url)
#         df.loc[i, 'MANUFACTURED_YEAR'] = manufactured_year_retrieval(listing_url)
#         df.loc[i, 'ROAD_TAX_YEARLY'] = road_tax_retrieval(listing_url)
#         df.loc[i, 'TRANSMISSION'] = transmission_retrieval(listing_url)
#         df.loc[i, 'DEREG_VALUE_FROM_SCRAPE_DATE'] = dereg_value_retrieval(listing_url)
#         df.loc[i, 'SCRAPE_DATE'] = datetime.now().strftime("%d/%m/%Y")
#         df.loc[i, 'OMV'] = omv_retrieval(listing_url)
#         df.loc[i, 'ARF'] = arf_retrieval(listing_url)
#         df.loc[i, 'COE_FROM_SCRAPE_DATE'] = coe_retrieval(listing_url)
#         df.loc[i, 'DAYS_OF_COE_LEFT'] = days_of_coe_retrieval(listing_url)
#         df.loc[i, 'ENGINE_CAPACITY_CC'] = engine_capacity_retrieval(listing_url)
#         df.loc[i, 'CURB_WEIGHT_KG'] = curb_weight_retrieval(listing_url)
#         df.loc[i, 'NO_OF_OWNERS'] = number_of_owners_retrieval(listing_url)
#         df.loc[i, 'VEHICLE_TYPE'] = type_of_vehicle_retrieval(listing_url)
#         df.loc[i, 'FUEL_TYPE'] = type_of_fuel_retrieval(listing_url)
#
#         time.sleep(5)  # Prevent getting blocked by the website
#
#     df.to_csv(f"{filename}.csv", index=True)

# %%
def scrape_car_data(listing_urls_csv, start_index, end_index, output_file):
    """
    Scrapes car data from the provided CSV file of listing URLs and saves it to a specified output file.

    Parameters:
    listing_urls_csv (str): The name of the input CSV file containing the URLs.
    start_index (int): The starting index of the URLs to process.
    end_index (int): The ending index of the URLs to process.
    output_file (str): The name of the output CSV file to save the scraped data.
    """
    # Read the CSV file into a DataFrame
    urls_df = pd.read_csv(listing_urls_csv)
    
    # Creating an empty DataFrame for attributes of interest
    df = pd.DataFrame(columns=[
        'LISTING_URL', 'BRAND', 'PRICE', 'DEPRE_YEARLY', 'REG_DATE', 'MILEAGE_KM',
        'MANUFACTURED_YEAR', 'ROAD_TAX_YEARLY', 'TRANSMISSION', 'DEREG_VALUE_FROM_SCRAPE_DATE',
        'SCRAPE_DATE', 'OMV', 'ARF', 'COE_FROM_SCRAPE_DATE', 'DAYS_OF_COE_LEFT',
        'ENGINE_CAPACITY_CC', 'CURB_WEIGHT_KG', 'NO_OF_OWNERS', 'VEHICLE_TYPE', 'FUEL_TYPE'
    ])

    for i, row in urls_df.iloc[start_index:end_index].iterrows():
        listingurl = row['URL']
        response = requests.get(listingurl)
        listing_url = BeautifulSoup(response.text, 'lxml')

        df.loc[i + start_index, 'LISTING_URL'] = listingurl
        df.loc[i + start_index, 'BRAND'] = brand_retrieval(listing_url)
        df.loc[i + start_index, 'PRICE'] = price_retrieval(listing_url)
        df.loc[i + start_index, 'DEPRE_YEARLY'] = depreciation_yearly_retrieval(listing_url)
        df.loc[i + start_index, 'REG_DATE'] = reg_date_retrieval(listing_url)
        df.loc[i + start_index, 'MILEAGE_KM'] = mileage_retrieval(listing_url)
        df.loc[i + start_index, 'MANUFACTURED_YEAR'] = manufactured_year_retrieval(listing_url)
        df.loc[i + start_index, 'ROAD_TAX_YEARLY'] = road_tax_retrieval(listing_url)
        df.loc[i + start_index, 'TRANSMISSION'] = transmission_retrieval(listing_url)
        df.loc[i + start_index, 'DEREG_VALUE_FROM_SCRAPE_DATE'] = dereg_value_retrieval(listing_url)
        df.loc[i + start_index, 'SCRAPE_DATE'] = datetime.now().strftime("%d/%m/%Y")
        df.loc[i + start_index, 'OMV'] = omv_retrieval(listing_url)
        df.loc[i + start_index, 'ARF'] = arf_retrieval(listing_url)
        df.loc[i + start_index, 'COE_FROM_SCRAPE_DATE'] = coe_retrieval(listing_url)
        df.loc[i + start_index, 'DAYS_OF_COE_LEFT'] = days_of_coe_retrieval(listing_url)
        df.loc[i + start_index, 'ENGINE_CAPACITY_CC'] = engine_capacity_retrieval(listing_url)
        df.loc[i + start_index, 'CURB_WEIGHT_KG'] = curb_weight_retrieval(listing_url)
        df.loc[i + start_index, 'NO_OF_OWNERS'] = number_of_owners_retrieval(listing_url)
        df.loc[i + start_index, 'VEHICLE_TYPE'] = type_of_vehicle_retrieval(listing_url)
        df.loc[i + start_index, 'FUEL_TYPE'] = type_of_fuel_retrieval(listing_url)

        time.sleep(1)  # Prevent getting blocked by the website

    df.to_csv(output_file, index=False)

# %%
listing_urls_length = len(listing_urls)  # or use len(listing_urls) if listing_urls is defined
interval = 200
file_names = []

for i in range(0, listing_urls_length, interval):
    start = i
    end = min(i + interval, listing_urls_length)
    file_index = (i // interval) + 1
    file_name = f'car_data_part{file_index:02d}.csv'
    file_names.append(file_name)
    scrape_car_data('listing_urls.csv', start, end, file_name)
    time.sleep(5)  # Pause for 5 seconds after each interval

# %% [markdown]
# # Concatenate the DataFrames from the generated CSV files
# dataframes = [pd.read_csv(file_name) for file_name in file_names]
#
# # Ensure all columns are aligned by reindexing
# all_columns = pd.Index([])
# for df in dataframes:
#     all_columns = all_columns.union(df.columns)
#
# dataframes = [df.reindex(columns=all_columns) for df in dataframes]
#
# combined_df = pd.concat(dataframes, ignore_index=True, join='outer')
#
# # Save the combined DataFrame to a new CSV file
# combined_df.to_csv('sgcarmart_used_cars_prices.csv', index=False)

# %%
# Concatenate the DataFrames from the generated CSV files
dataframes = [pd.read_csv(file_name) for file_name in file_names]
combined_df = pd.concat(dataframes, ignore_index=True)

# Save the combined DataFrame to a new CSV file
combined_df.to_csv('sgcarmart_used_cars_prices.csv', index=True)

# Check the number of listings
print(f"Total number of listings: {combined_df.shape[0]}")
# Out:
# Total number of listings: 9926

# %% [markdown]
# #scrape_car_data(listing_urls)
# df = pd.read_csv('sgcarmart_used_cars_prices.csv',index_col=0)
# df
